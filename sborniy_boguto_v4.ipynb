# %% [markdown]
# <div class="alert alert-info">
# Привет, Елена! Меня зовут Светлана Чих и я буду проверять твой проект. Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе. Предлагаю общаться на «ты». Но если это не удобно - дай знать, и мы перейдем на «вы».
#
# <div class="alert alert-success">
# <b>👍 Успех:</b> Зелёным цветом отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах.
# </div>
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Жёлтым цветом выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
# </div>
# <div class="alert alert-danger">
# <b>😔 Необходимо исправить:</b> Красным цветом выделены комментарии, без исправления которых, я не смогу принять проект :(
# </div>
# <div class="alert alert-info">
# <b>👂 Совет:</b> Какие-то дополнительные материалы
# </div>
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом.
# Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>🎓 Комментарий студента:</b> Например, вот так.</div>
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#  </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#План-проекта" data-toc-modified-id="План-проекта-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>План проекта</a></span></li><li><span><a href="#Загрузка-и-импорт-библиотек" data-toc-modified-id="Загрузка-и-импорт-библиотек-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка и импорт библиотек</a></span></li><li><span><a href="#Первый-этап:-загрузка-данных-из-таблиц" data-toc-modified-id="Первый-этап:-загрузка-данных-из-таблиц-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Первый этап: загрузка данных из таблиц</a></span></li><li><span><a href="#Второй-этап:-первичное-исследование-таблиц" data-toc-modified-id="Второй-этап:-первичное-исследование-таблиц-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Второй этап: первичное исследование таблиц</a></span><ul class="toc-item"><li><span><a href="#Таблица-Vehicles" data-toc-modified-id="Таблица-Vehicles-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Таблица Vehicles</a></span></li><li><span><a href="#Таблица-Parties" data-toc-modified-id="Таблица-Parties-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Таблица Parties</a></span></li><li><span><a href="#Таблица-Collisions" data-toc-modified-id="Таблица-Collisions-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Таблица Collisions</a></span></li></ul></li><li><span><a href="#Третий-этап:-статистический-анализ-факторов-ДТП" data-toc-modified-id="Третий-этап:-статистический-анализ-факторов-ДТП-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Третий этап: статистический анализ факторов ДТП</a></span><ul class="toc-item"><li><span><a href="#Сравнение-количества-ДТП-по-месяцам-года" data-toc-modified-id="Сравнение-количества-ДТП-по-месяцам-года-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Сравнение количества ДТП по месяцам года</a></span></li><li><span><a href="#Примеры-аналитических-задач-для-коллег" data-toc-modified-id="Примеры-аналитических-задач-для-коллег-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Примеры аналитических задач для коллег</a></span><ul class="toc-item"><li><span><a href="#Задача-1.-Количество-ДТП-по-годам" data-toc-modified-id="Задача-1.-Количество-ДТП-по-годам-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Задача 1. Количество ДТП по годам</a></span></li><li><span><a href="#Задача-2.-Доля-ДТП-с-нетрезвым-водителем." data-toc-modified-id="Задача-2.-Доля-ДТП-с-нетрезвым-водителем.-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Задача 2. Доля ДТП с нетрезвым водителем.</a></span></li><li><span><a href="#Задача-3.-Типы-ДТП-на-обледенелой-дороге.-С-графиком." data-toc-modified-id="Задача-3.-Типы-ДТП-на-обледенелой-дороге.-С-графиком.-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Задача 3. Типы ДТП на обледенелой дороге. С графиком.</a></span></li><li><span><a href="#Задача-4.-Страховки-и-типы-авто.-С-графиком." data-toc-modified-id="Задача-4.-Страховки-и-типы-авто.-С-графиком.-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Задача 4. Страховки и типы авто. С графиком.</a></span></li><li><span><a href="#Задача-5.-Влияние-мобильного-телефона-на-вину-участника" data-toc-modified-id="Задача-5.-Влияние-мобильного-телефона-на-вину-участника-6.2.5"><span class="toc-item-num">6.2.5&nbsp;&nbsp;</span>Задача 5. Влияние мобильного телефона на вину участника</a></span></li><li><span><a href="#Задача-6.-Город-ДТП-и-наличие-алгоколя-в-крови." data-toc-modified-id="Задача-6.-Город-ДТП-и-наличие-алгоколя-в-крови.-6.2.6"><span class="toc-item-num">6.2.6&nbsp;&nbsp;</span>Задача 6. Город ДТП и наличие алгоколя в крови.</a></span></li></ul></li></ul></li><li><span><a href="#Четвертый-этап.-Создание-модели-для-оценки-водительского-риска" data-toc-modified-id="Четвертый-этап.-Создание-модели-для-оценки-водительского-риска-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Четвертый этап. Создание модели для оценки водительского риска</a></span><ul class="toc-item"><li><span><a href="#Отбор-данных-на-основе-первичного-предположения-заказчика" data-toc-modified-id="Отбор-данных-на-основе-первичного-предположения-заказчика-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Отбор данных на основе первичного предположения заказчика</a></span></li><li><span><a href="#Первичный-отбор-параметров" data-toc-modified-id="Первичный-отбор-параметров-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Первичный отбор параметров</a></span></li><li><span><a href="#Предобработка-выборки" data-toc-modified-id="Предобработка-выборки-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Предобработка выборки</a></span></li><li><span><a href="#Исследовательский-анализ-выборки" data-toc-modified-id="Исследовательский-анализ-выборки-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Исследовательский анализ выборки</a></span></li><li><span><a href="#Подготовка-данных-для-модели" data-toc-modified-id="Подготовка-данных-для-модели-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Подготовка данных для модели</a></span></li></ul></li><li><span><a href="#Пятый-этап.-Поиск-лучшей-модели" data-toc-modified-id="Пятый-этап.-Поиск-лучшей-модели-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Пятый этап. Поиск лучшей модели</a></span><ul class="toc-item"><li><span><a href="#Поиск-модели-среди-классификаторов" data-toc-modified-id="Поиск-модели-среди-классификаторов-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Поиск модели среди классификаторов</a></span><ul class="toc-item"><li><span><a href="#Модель-DecisionTreeClassifier" data-toc-modified-id="Модель-DecisionTreeClassifier-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Модель DecisionTreeClassifier</a></span></li><li><span><a href="#Модель-KNeighborsClassifier" data-toc-modified-id="Модель-KNeighborsClassifier-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>Модель KNeighborsClassifier</a></span></li><li><span><a href="#Модель-LogisticRegression" data-toc-modified-id="Модель-LogisticRegression-8.1.3"><span class="toc-item-num">8.1.3&nbsp;&nbsp;</span>Модель LogisticRegression</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-8.1.4"><span class="toc-item-num">8.1.4&nbsp;&nbsp;</span>Сравнение моделей</a></span></li></ul></li></ul></li><li><span><a href="#Шестой-этап.-Анализ-метрики-лучшей-модели" data-toc-modified-id="Шестой-этап.-Анализ-метрики-лучшей-модели-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Шестой этап. Анализ метрики лучшей модели</a></span><ul class="toc-item"><li><span><a href="#Матрица-ошибок,-полнота-и-точность" data-toc-modified-id="Матрица-ошибок,-полнота-и-точность-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Матрица ошибок, полнота и точность</a></span></li><li><span><a href="#Анализ-важности-признаков-для-модели" data-toc-modified-id="Анализ-важности-признаков-для-модели-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Анализ важности признаков для модели</a></span></li><li><span><a href="#Влияние-одного-из-важных-признаков-на-целевой-показатель" data-toc-modified-id="Влияние-одного-из-важных-признаков-на-целевой-показатель-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Влияние одного из важных признаков на целевой показатель</a></span></li></ul></li><li><span><a href="#Седьмой-этап.-Общий-вывод" data-toc-modified-id="Седьмой-этап.-Общий-вывод-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Седьмой этап. Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Сборный проект 3, 4

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# В этом проекте мы пытаемся создать систему, которая могла бы оценить риск ДТП по выбранному маршруту движения. Под риском понимается вероятность ДТП с любым повреждением транспортного средства. Как только водитель забронировал автомобиль, сел за руль и выбрал маршрут, система должна оценить уровень риска. Если уровень риска высок, водитель увидит предупреждение и рекомендации по маршруту.
#
# Идея создания такой системы находится в стадии предварительного обсуждения и проработки. Чёткого алгоритма работы и подобных решений на рынке ещё не существует. Текущая задача — понять, возможно ли предсказывать ДТП, опираясь на исторические данные одного из регионов.
#
# Заказчик предалагет следующие шаги:
# 1. Создать модель предсказания ДТП (целевое значение — at_fault (виновник) в таблице parties)
# - a. Для модели выбрать тип виновника — только машина (car).
# - b. Выбрать случаи, когда ДТП привело к любым повреждениям транспортного средства, кроме типа SCRATCH (царапина).
# - c. Для моделирования ограничиться данными за 2012 год — они самые свежие.
# - d. Обязательное условие — учесть фактор возраста автомобиля.
#
# 2. На основе модели исследовать основные факторы ДТП.
#
#
# 3. Понять, помогут ли результаты моделирования и анализ важности факторов ответить на вопросы:
# - a. Возможно ли создать адекватную системы оценки водительского риска при выдаче авто?
# - b. Какие ещё факторы нужно учесть?
# - c. Нужно ли оборудовать автомобиль какими-либо датчиками или камерой?

# %% [markdown]
# ## План проекта

# %% [markdown]
# **Первый этап**: загрузить таблицы sql, подключившись к базе.
#
# **Второй этап**: произвести первичное исследование таблиц, используя sql-запросы.
# - Проверить, все ли таблицы имеют набор данных
# - Проверить, соответствует ли количество таблиц условию задачи
# - Проверить, имеется ли общий ключ для связи таблиц.
#
# **Третий этап:** произвести статистический анализ факторов ДТП.
# 1. Выяснить, в какие месяцы происходит наибольшее количество аварий, проанализировав весь период наблюдений.
# - необходимо создать sql-Запрос
# - построить график
# - сделать вывод.
# 2. Создать несколько (не менее шести) аналитических задач для гипотетических коллег, связанных с данными.
# Примеры задач:
# - Проведите анализ серьёзности повреждений транспортного средства, исходя из состояния дороги в момент ДТП (связать collisions и parties);
# - Найдите самые частые причины ДТП (таблица parties).
#
# Прописать порядок решения и реализовать его для двух задач из списка. Решение задач должно включать в себя связь не менее двух таблиц, а ответ должен быть визуализирован, и содержать вывод.
#
# **Четвертый этап:** создать модель для оценки водительского риска.
# 1. Подготовить набор данных на основе первичного предположения заказчика:
# - тип виновника - только машина (car)
# - использовать случаи, когда ДТП привело к любым значимым повреждениям автомобиля любого из участников — все, кроме типа SCRATCH (царапина)
# - для моделирования использовать данные только за 2012 год.
# - Подготовка исходной таблицы должна проводиться с помощью sql-запроса.
#
# 2. Провести первичный отбор факторов, необходимых для модели. Отобрать те, что могут влиять на вероятность ДТП, и аргументировать свой выбор.
#
# 3. Провести статистическое исследование отобранных факторов:
# - если необходимо, внести корректировки в данные по результатам исследовательского анализа. Написать вывод.
# - если необходимо, то категоризировать исходные данные, произвести масштабирование.
# - подготовить обучающую и тестовую выборки.
#
# **Пятый этап:** поиск лучшей модели.
#
# 1. Использовать в работе не менее трех типов моделей с перебором гиперпараметров.
# 2. Выбрать метрика для оценки модели, исходя из поставленной бизнесом задачи. Обосновать свой выбор.
# 3. Оформить вывод в виде сравнительной таблицы.
#
# **Шестой этап:** проверка лучшей модели в работе.
# 1. Произвести графический анализ "Матрица ошибок". Вывести значения "полноты" и "точности" на график.
# 2. Проанализировать важность основных факторов, влияющих на вероятность ДТП.
# 3. Для одного из выявленных важных факторов провести дополнительное исследование:
# - создать график зависимости целевой переменной и фактора;
# - предложить, чем можно оборудовать автомобиль, чтобы учесть этот фактор во время посадки водителя.
#
# **Седьмой этап:** общий вывод о модели.
# - кратко описать лучшую модель;
# - описать, насколько возможно создание адекватнойсистемы оценки риска при выдаче авто;
# - какие еще факторы необходимо собирать, чтобы улучшить модель.

# %% [markdown]
# ## Загрузка и импорт библиотек

# %%
# обновляю библиотеку

# !pip install --upgrade scikit-learn -q

# %%
# установим библиотеку для sql

# !pip install sqlalchemy -q

# %%
# библиотеку, возможно, придется установить

#!pip install missingno -q

# %%
# библиотеку, возможно, нужно установить

# !pip install shap -q

# %%
# импортируем библиотеки

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import missingno as msno
import sklearn
import shap

import datetime


# загружаем модели машинного обучения

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# импортируем методы

from sqlalchemy import create_engine 


# загружаем классы для работы с данными

from sklearn.model_selection import (train_test_split, 
                                    cross_val_score,
                                    GridSearchCV)

from sklearn.preprocessing import (OneHotEncoder, 
                                   StandardScaler, 
                                   MinMaxScaler,
                                   RobustScaler)

# загрузим класс для работы с пропусками
from sklearn.impute import SimpleImputer

from sklearn.pipeline import Pipeline

from sklearn.compose import ColumnTransformer


# загружаем метрику

from sklearn.metrics import (roc_auc_score,
                            precision_recall_curve,
                            RocCurveDisplay)


# константы

RANDOM_STATE = 42

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Импортированы нужные библиотеки!
# </div>

# %% [markdown]
# ## Первый этап: загрузка данных из таблиц

# %%
# вводим данные для подключения к базе

db_config = {
'user': 'praktikum_student', # имя пользователя,
'pwd': 'Sdf4$2;d-d30pp', # пароль,
'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
'port': 6432, # порт подключения,
'db': 'data-science-vehicle-db' # название базы данных,
}

# %%
# создаем строку с данными и формируем "движитель"

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db'],
) 

engine = create_engine(connection_string)

# %%
# создаем запрос на первую таблицу с данными об авто и формируем на ее основе датафрейм

query_df_vehicles = '''
SELECT *
FROM vehicles
LIMIT 15;
'''

df_vehicles = pd.read_sql_query(query_df_vehicles, con= engine)

# %%
# создаем запрос на вторую таблицу с данными и формируем на ее основе датафрейм

query_df_collisions = '''
SELECT *
FROM collisions
LIMIT 15;
'''

df_collisions = pd.read_sql_query(query_df_collisions, con= engine)

# %%
# создаем запрос на третью таблицу с данными и формируем на ее основе датафрейм

query_df_parties = '''
SELECT *
FROM parties
LIMIT 15;
'''

df_parties = pd.read_sql_query(query_df_parties, con= engine)

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Не нужно выкачивать полностью БД, на этом этапе умирает ядро, потому что данных слишком много</s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я исправлю, но... Раздел называется "загрузка таблицы SQL". И у меня данные вполне загружались, без умирания ядра. Получается под "загрузкой" разработчики задания подразумевали только "подключение".
#
# Тогда и в "первичном исследовании таблиц" придется смотреть на "огрызки", а не полные данные. Жаль. Надеюсь, в реальных проектах такого ограничения не будет. Если я могу забрать данные, значит, могу.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> В реальной жизни ограничения довольно жесткие. Зачем забирать все даннные? Что бы просто тратить ресурсы? Достаточно понимать какие данные есть в теблицах, то есть названия полей и смысл лежащих там данных, их тип, возможно уникальные значения. Если данные находятся в разных таблицах, то нужно понимать как из объединить (часто столбцы называются по разному в разных таблицах). Данные отбираются строго под решение какой то задачи. В реальной жизни таблицы могут содержать триллионы строк. Задача оптимизаии использования ресурсов очень важна, многие компании уже на собеседованиях ставят задачи не просто проверяющие зумение писать запросы, но и насколько оптимально кандидат пишет запросы и обращает ли он на это внимание.
#
# В первичном исследовании тебе достаточно посмотреть на несколько строк, понять тип данных, количество строк (при желании уникалльные значения, минимальное и маквимальное значение), все можно вытащить запросом не выгружая БД.
# </div>

# %% [markdown]
# ## Второй этап: первичное исследование таблиц

# %% [markdown]
# ### Таблица Vehicles

# %%
# query = '''
# SELECT *
# FROM vehicles
# LIMIT 5;
# '''
# display(pd.read_sql_query(query, con=engine))
# pd.read_sql_query(query, con=engine).info()

# %%
# посмотрим данные о первом файле

pd.read_sql_query(query_df_vehicles, con=engine).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15 non-null     int64
#  1   case_id               15 non-null     object
#  2   party_number          15 non-null     int64
#  3   vehicle_type          15 non-null     object
#  4   vehicle_transmission  15 non-null     object
#  5   vehicle_age           15 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 848.0+ bytes

# %% [markdown]
# В данных есть пропуски.
#
# ![image.png](attachment:image.png) Названия колонок соответствуют описанию БД. Тип данных в параметре `vehicle age` не соответствует описанию. Ожидали int, а указан float. Нужно будет проверить.
#
# Посмотрим, есть ли зависимость в пропусках данных.

# %%
# изучим пропуски в первом файле

#msno.matrix(df_vehicles);

# %%
# пожалуй, на взгляд зависимость не видна
# проверим

#msno.heatmap(df_vehicles);

# %% [markdown]
# ~~Диаграмма тоже не подтверждает взаимосвязи между пропущенными значениями.~~

# %%
# изучим уникальность значений наших признаков

for column in df_vehicles.columns:
        print(column)
        print(df_vehicles[column].value_counts())
        print("Доля пропущенные значений:", round((df_vehicles[column].isna().mean()*100), 2))
        print()
# Out:
# id
# 1175712    1
# 1175713    1
# 1175778    1
# 1175715    1
# 1175716    1
# 1175717    1
# 1175750    1
# 1175720    1
# 1175722    1
# 1175724    1
# 1175758    1
# 1175792    1
# 1          1
# 6          1
# 1175737    1
# Name: id, dtype: int64
# Доля пропущенные значений: 0.0
#
# case_id
# 5305033    4
# 5305034    2
# 5305080    1
# 5305046    1
# 5305032    1
# 5305053    1
# 5305071    1
# 3858022    1
# 3899454    1
# 5305030    1
# 5305060    1
# Name: case_id, dtype: int64
# Доля пропущенные значений: 0.0
#
# party_number
# 1    6
# 2    5
# 3    2
# 4    2
# Name: party_number, dtype: int64
# Доля пропущенные значений: 0.0
#
# vehicle_type
# sedan        14
# hatchback     1
# Name: vehicle_type, dtype: int64
# Доля пропущенные значений: 0.0
#
# vehicle_transmission
# auto      10
# manual     5
# Name: vehicle_transmission, dtype: int64
# Доля пропущенные значений: 0.0
#
# vehicle_age
# 3     3
# 5     3
# 4     2
# 10    2
# 11    2
# 1     1
# 6     1
# 9     1
# ...

# %% [markdown]
# Из первой версии проекта, где я выгружала полные данные таблиц было видно, что у нас в данных:
# - каждой строке соответствует уникальный id
# - количество `case id` - идентификаторов происшествия - меньше, чем число всех записей. Можно полагать, что это объясняется наличием нескольких участников в происшествии, каждому автомобилю которого в записях есть строка
# - номер участника происшествия принимает целые значения, от 1 до 27. Нулевых нет.
# - среди типов автомобиля пропущенных значений нет, но есть некоторые с типом `other`.
# - среди данных о коробке передач есть пропущенные значения. Их стоит заменить заглушкой.
# - среди возраста автомобилей есть и пропущенные, и необычное значение в 161 год. В 1858 году автомобилей еще не было, как таковых. Скорее всего, эти строки придется удалить из датафрейма.

# %%
# посмотрим, что это за автомобили-рекодсмены

#df_vehicles.query('vehicle_age == 161.0')

# %% [markdown]
# ### Таблица Parties

# %%
# query = '''
# SELECT *
# FROM parties
# LIMIT 5;
# '''
# display(pd.read_sql_query(query, con=engine))
# pd.read_sql_query(query, con=engine).info()

# %%
# посмотрим данные о втором файле

pd.read_sql_query(query_df_parties, con=engine).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   15 non-null     int64
#  1   case_id              15 non-null     object
#  2   party_number         15 non-null     int64
#  3   party_type           14 non-null     object
#  4   at_fault             15 non-null     int64
#  5   insurance_premium    5 non-null      float64
#  6   party_sobriety       14 non-null     object
#  7   party_drug_physical  7 non-null      object
#  8   cellphone_in_use     13 non-null     float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 1.2+ KB

# %% [markdown]
# ![image-2.png](attachment:image-2.png) Названия колонок соответствуют описанию БД. Тип данных в параметрах `insurance_premium` и `cellphone_in_use` не соответствует описанию. Ожидали int, а указан float. Нужно будет проверить.
#
# Посмотрим, есть ли зависимость в пропусках данных.

# %%
# изучим пропуски в первом файле

#msno.matrix(df_parties);

# %%
# посмотрим на взаимозависимость пропусков

#msno.heatmap(df_parties);

# %% [markdown]
# Похоже, что если для ДТП отмечено отклонение в состоянии участника, то не будет заполнена сумма страховки.

# %%
# изучим уникальность значений наших признаков

for column in df_parties.columns:
        print(column)
        print(df_parties[column].value_counts())
        print("Доля пропущенные значений:", round((df_parties[column].isna().mean()*100), 2))
        print()
# Out:
# id
# 41     1
# 135    1
# 72     1
# 73     1
# 43     1
# 76     1
# 142    1
# 111    1
# 115    1
# 22     1
# 23     1
# 29     1
# 93     1
# 126    1
# 31     1
# Name: id, dtype: int64
# Доля пропущенные значений: 0.0
#
# case_id
# 3899505    2
# 3899454    2
# 3899478    1
# 3981292    1
# 3982898    1
# 3899481    1
# 3982892    1
# 3899462    1
# 3982076    1
# 3982068    1
# 3982887    1
# 3899509    1
# 3899465    1
# Name: case_id, dtype: int64
# Доля пропущенные значений: 0.0
#
# party_number
# 2    11
# 1     3
# 3     1
# Name: party_number, dtype: int64
# Доля пропущенные значений: 0.0
#
# party_type
# road bumper    9
# road signs     3
# car            2
# Name: party_type, dtype: int64
# Доля пропущенные значений: 6.67
#
# at_fault
# 0    13
# 1     2
# Name: at_fault, dtype: int64
# Доля пропущенные значений: 0.0
#
# insurance_premium
# 7.0     1
# 21.0    1
# 24.0    1
# 71.0    1
# 29.0    1
# Name: insurance_premium, dtype: int64
# ...

# %% [markdown]
# Из первой версии проекта, где я выгружала полные данные таблиц было видно, что у нас в данных:
# - каждой строке соответствует уникальный id
# - количество `case id` - идентификаторов происшествия - меньше, чем число всех записей. И при этом, в таблице Vehicles у нас 792 642 уникальных номера происшествия, а в таблице Parties - 1 400 000. Почти в два раза больше. Может ли это означать, что второй участник происшествия не имел транспортного средства? Столкновение с пешеходом, например.
# - Номер участника происшествия принимает целые значения, от 1 до 27. Нулевых нет.
# - в типе происшествия отсутствуют значения `operator` из описания данных.
# - в сумме страховки пропущено порядка 14% строк, но отсутствуют нулевые значения. Можно предположить, что пропуски соответствуют отсутствию страховки.
# - в параметре трезвости участника пропущено 2,7% значений.
# - в параметре `party drug phisical` - "Состояние участника: физическое или с учётом принятых лекарств" - пропущено более 84% строк. При этом значение параметра G означает, что состояние участница неизвестно.
# - параметр, связанный с возможностью разговаривать по громкой связи в автомобиле, не расшифрован. Можно предположить, что "0" - означает "нет", а "1" означает "да".

# %% [markdown]
# ### Таблица Collisions

# %%
# query = '''
# SELECT *
# FROM collisions
# LIMIT 5;
# '''
# display(pd.read_sql_query(query, con=engine))
# pd.read_sql_query(query, con=engine).info()

# %%
pd.read_sql_query(query_df_collisions, con=engine).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   case_id                      15 non-null     object
#  1   county_city_location         15 non-null     object
#  2   county_location              15 non-null     object
#  3   distance                     15 non-null     float64
#  4   direction                    5 non-null      object
#  5   intersection                 15 non-null     int64
#  6   weather_1                    15 non-null     object
#  7   location_type                7 non-null      object
#  8   collision_damage             15 non-null     object
#  9   party_count                  15 non-null     int64
#  10  primary_collision_factor     15 non-null     object
#  11  pcf_violation_category       14 non-null     object
#  12  type_of_collision            15 non-null     object
# ...

# %% [markdown]
# В данных есть пропуски.
#
# ![image-3.png](attachment:image-3.png) Названия колонок соответствуют описанию БД. Тип данных в параметре `collision_date` не соответствует описанию. Ожидали date, а указан object. Нужно будет проверить.
#
# Посмотрим, есть ли зависимость в пропусках данных.

# %%
# изучим пропуски в первом файле

#msno.matrix(df_collisions);

# %%
# проверим взаимосвязь в пропусках

#msno.heatmap(df_collisions);

# %% [markdown]
# Есть некоторая зависимость между "Погодой" и "Состоянием дороги" и "Освещением".
#
# А также есть связь между "Категорией нарушения" и "Основным фактором аварии".
#
# Если пропущены данные в одном из этих параметров, то с 50% случаев будут пропущены и в связанном с ним.

# %%
# изучим уникальность значений наших признаков

for column in df_collisions.columns:
        print(column)
        print(df_collisions[column].value_counts())
        print("Доля пропущенные значений:", round((df_collisions[column].isna().mean()*100), 2))
        print()
# Out:
# case_id
# 4083100    1
# 4083097    1
# 4083120    1
# 4083077    1
# 4083116    1
# 4083107    1
# 4083103    1
# 4083072    1
# 4083111    1
# 4083073    1
# 4083087    1
# 4083092    1
# 4083112    1
# 4083075    1
# 4083096    1
# Name: case_id, dtype: int64
# Доля пропущенные значений: 0.0
#
# county_city_location
# 4313    5
# 1942    4
# 1950    3
# 0109    3
# Name: county_city_location, dtype: int64
# Доля пропущенные значений: 0.0
#
# county_location
# los angeles    7
# santa clara    5
# alameda        3
# Name: county_location, dtype: int64
# Доля пропущенные значений: 0.0
#
# distance
# 0.0       10
# 200.0      1
# 2112.0     1
# 528.0      1
# 1320.0     1
# 120.0      1
# Name: distance, dtype: int64
# Доля пропущенные значений: 0.0
#
# direction
# north    2
# south    2
# west     1
# Name: direction, dtype: int64
# Доля пропущенные значений: 66.67
#
# intersection
# 1    10
# 0     5
# Name: intersection, dtype: int64
# Доля пропущенные значений: 0.0
#
# ...

# %% [markdown]
# Из первой версии проекта, где я выгружала полные данные таблиц было видно, что у нас в данных:
# - у нас нет колонки id
# - количество `case id` - идентификаторов происшествия - 1 400 000, как и в таблице Parties.
# - пропусков в географических данных нет.
# - параметр distance - расстояние от главной дороги - зафиксирован очень подробно.
# - есть пропуски в параметре "направление движения".
# - есть незначительное количество пропусков в параметре "является ли место происшествия перекрестком".
# - есть незначительное количество пропусков в параметре "погоды", но есть и вариант параметра "другое".
# - значительное количество пропусков в параметре "тип дороги". Неясно, в чем может быть причина. ДТП произошло не на дороге?
# - параметр с серьезностью повреждений не содержит пропусков.
# - параметр `party count` здесь подразумевает количество участников, а не их порядковый номер, как в других таблицах.
# - в остальных признаках очень много категорийных значений, которые не всегда соответствуют таблице расшифровки из задания.в А также присутствует небольшое количество пропусков.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> С данными ознакомились! Стоило вывести результаты запросов, что бы посмотреть на них
# </div>

# %% [markdown]
# ## Третий этап: статистический анализ факторов ДТП

# %% [markdown]
# ### Сравнение количества ДТП по месяцам года

# %% [markdown]
# По условию задачи, нам нужно выяснить, в какие месяцы из всего периода наблюдений происходит наибольшее количество аварий. Для этого нам нужна таблица collisions, все строки в ней обладают уникальными case_id. И колонка с датой ДТП.

# %%
# создадим запрос

query_month_col = '''
                    SELECT EXTRACT(YEAR FROM collision_date::date):: int AS col_year,
                           EXTRACT(MONTH FROM collision_date::date):: int AS month_of_year,
                           COUNT (DISTINCT case_id) AS collisions_count
                    FROM collisions
                    GROUP BY EXTRACT(YEAR FROM collision_date::date),
                             EXTRACT(MONTH FROM collision_date::date);
                    '''

month_col = pd.read_sql_query(query_month_col, con=engine)

month_col
# Out:
#     col_year  month_of_year  collisions_count
# 0       2009              1             35062
# 1       2009              2             34480
# 2       2009              3             36648
# 3       2009              4             35239
# 4       2009              5             36916
# 5       2009              6             34202
# 6       2009              7             35161
# 7       2009              8             34508
# 8       2009              9             35555
# 9       2009             10             37835
# 10      2009             11             34562
# 11      2009             12             36060
# 12      2010              1             32892
# 13      2010              2             31918
# 14      2010              3             35803
# 15      2010              4             34416
# 16      2010              5             34862
# 17      2010              6             33367
# 18      2010              7             33645
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Нужно сначала проверить полноту данных, по всем месяцам и годам данные полные? Неполные данные искажают информацию и получаются неверные выводы</s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ну вот опять завуалированное задание.
#
# ![image.png](attachment:image.png)
#
# Что именно должно было натолкнуть меня на вывод, что нужные данные за каждый месяц каждого года по отдельности?
#
# Исправляю.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Это не завуалированное задание, в предыдущих модулях была информация о предобработке и исследовании данных, о том почему это нужно делать, и что данные могут прийти абсолютно любые, с аномалиями, неполные, не в том формате (все что угодно), то есть первое, что нужно сделать - проверить полноту и определнить с чем работать. Здесь можно оставить предыдущий график, но в запросе добавить уловие по году - до 2012, так как видно, что уже в 2012 году данные неполные.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Нельзя, ведь явно указано проанализировать весь период наблюдений. Ладно, я просто конкретно за 2012 год изучала в отдельной задаче.

# %%
sns.catplot(data=month_col, x="month_of_year", y='collisions_count',
            col="col_year", kind="bar", col_wrap=2, height=3, aspect=1.2);

# %% [markdown]
# Исходя из графика, ~~летом происходит меньше всего ДТП. Наиболее часто ДТП происходят **в марте**. Далее, **в январе**. В принципе, в **первые пять месяцев года** количество ДТП превышает эти значения для остальных месяцев. Безусловно, все это верно только для рассматриваемого массива данных.~~
# мы работаем с несбалансированными данными. Если в 2009-2011 годах количества ДТП по месяцам распредено более-менее равномерно, то в 2012 данные после июня практически отсутствуют, а данные за 2013 и 2020 год воообще, скорее всего, ошибочны.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %%
# посмотрим, в каком периоде зафиксированы данные

# query = '''
# SELECT MIN (DATE_TRUNC ('day', collision_date)),
#        MAX (DATE_TRUNC ('day', collision_date))
# FROM collisions;
# '''
# display(pd.read_sql_query(query, con=engine))

# %% [markdown]
# ~~Интервал довольно велик: с начала 2009 года до середины 2020 года.~~

# %% [markdown]
# ### Примеры аналитических задач для коллег

# %% [markdown]
# #### Задача 1. Количество ДТП по годам

# %% [markdown]
# Оценить количество ДТП в данных по годам. Действительно ли данные за 2012 год являются наиболее подходящими для построения модели?

# %%
# создадим запрос

query_year_col = '''
                    SELECT EXTRACT(YEAR FROM collision_date)::int AS year,
                           COUNT (DISTINCT case_id) AS collisions_count
                    FROM collisions
                    GROUP BY EXTRACT(YEAR FROM collision_date)
                    ORDER BY (COUNT (DISTINCT case_id)) DESC;
                    '''

year_col = pd.read_sql_query(query_year_col, con=engine)

year_col
# Out:
#    year  collisions_count
# 0  2009            426228
# 1  2010            416490
# 2  2011            402428
# 3  2012            154547
# 4  2013               305
# 5  2020                 2

# %% [markdown]
# Исходя из результата, данные за 2012 год действительно являются самыми "свежими", но далеко не самыми полными. Такое сокращение количества ДТП между 2009-2011 годами и 2012 не может быть закономерным. Я полагаю, что как число автомобилей во всем мире растет, так и количество ДТП должно только увеличиваться. **Возможно, данные за 2012 год неполные. В этом случае использовать их в качестве выборки для обучения модели было бы не слишком разумно.**
#
# Данные за 2020 год попали в выборку по ошибке, все данные в курсе DS+ были сняты в 2019 году.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Да, они действительно неполные, но самые свежие
# </div>

# %% [markdown]
# #### Задача 2. Доля ДТП с нетрезвым водителем.

# %% [markdown]
# Какую часть ДТП с участием нетрезвого водителя составляет от года к году для данных 2009-2012 годов?

# %%
# создадим запрос

query_drunk = '''
SELECT EXTRACT(YEAR FROM c.collision_date)::int AS year,
       COUNT (c.case_id) AS drunk_count
       
FROM collisions AS c 

JOIN parties AS p ON c.case_id = p.case_id

WHERE p.party_sobriety LIKE 'had been drinking%%'
AND
(EXTRACT(YEAR FROM c.collision_date)::int) IN (2009, 2010, 2011, 2012)

GROUP BY EXTRACT(YEAR FROM c.collision_date)::int;
'''

df_drunk = pd.read_sql_query(query_drunk, con=engine)
df_drunk
# Out:
#    year  drunk_count
# 0  2009        47179
# 1  2010        44234
# 2  2011        43310
# 3  2012        16658

# %%
# объединим с прошлым запросом и посчитаем долю

df_drunk_col = df_drunk.merge(year_col, on='year', how='inner')

df_drunk_col['percent'] = df_drunk_col['drunk_count'] / df_drunk_col['collisions_count']*100

df_drunk_col
# Out:
#    year  drunk_count  collisions_count    percent
# 0  2009        47179            426228  11.068958
# 1  2010        44234            416490  10.620663
# 2  2011        43310            402428  10.762174
# 3  2012        16658            154547  10.778598

# %% [markdown]
# Доля ДТП с участием нетрезвого водителя для всех рассматриваемых годов не превышает 11% от общего количества ДТП.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# #### Задача 3. Типы ДТП на обледенелой дороге. С графиком.

# %% [markdown]
# Какого типа ДТП чаще случались на обледенелой дороге?

# %% [markdown]
# Состояние дороги описано в таблице collisions, параметр road surface. Тип ДТП указан в таблице parties, параметр party_type.

# %%
#

query_road_surface = '''
SELECT EXTRACT(MONTH FROM collision_date::date)::int AS month_of_year,
       p.party_type,
       COUNT(p.party_type) 

FROM collisions AS c 

JOIN parties AS p ON c.case_id = p.case_id

WHERE c.road_surface = 'snowy'
GROUP BY EXTRACT(MONTH FROM collision_date::date)::int, p.party_type
ORDER BY EXTRACT(MONTH FROM collision_date::date)::int, COUNT(p.party_type) DESC;
'''

df_road_surf = pd.read_sql_query(query_road_surface, con=engine)

df_road_surf
# Out:
#     month_of_year   party_type  count
# 0               1          car   1882
# 1               1  road bumper    111
# 2               1        other     67
# 3               1   road signs     20
# 4               1     building      1
# 5               1         None      0
# 6               2          car   2311
# 7               2        other    149
# 8               2  road bumper    134
# 9               2   road signs     34
# 10              2     building      1
# 11              2         None      0
# 12              3          car   1696
# 13              3        other     98
# 14              3  road bumper     94
# 15              3   road signs     32
# 16              3     building      2
# 17              3         None      0
# 18              4          car    746
# 19              4  road bumper     27
# 20              4        other     21
# 21              4   road signs      4
# 22              4     building      2
# 23              4         None      0
# ...

# %%
fig, axes = plt.subplots(4, 3, figsize=(12,12));
plt.subplots_adjust(wspace=0.8, hspace=1.0)

sns.barplot(data=df_road_surf.query('month_of_year==1'), y='party_type', x='count', ax=axes[0, 0]).set (title='Январь');
sns.barplot(data=df_road_surf.query('month_of_year==2'), y='party_type', x='count', ax=axes[0, 1]).set (title='Февраль');
sns.barplot(data=df_road_surf.query('month_of_year==3'), y='party_type', x='count', ax=axes[0, 2]).set (title='Март');
sns.barplot(data=df_road_surf.query('month_of_year==4'), y='party_type', x='count', ax=axes[1, 0]).set (title='Апрель');
sns.barplot(data=df_road_surf.query('month_of_year==5'), y='party_type', x='count', ax=axes[1, 1]).set (title='Май');
sns.barplot(data=df_road_surf.query('month_of_year==6'), y='party_type', x='count', ax=axes[1, 2]).set (title='Июнь');
sns.barplot(data=df_road_surf.query('month_of_year==7'), y='party_type', x='count', ax=axes[2, 0]).set (title='Июль');
sns.barplot(data=df_road_surf.query('month_of_year==8'), y='party_type', x='count', ax=axes[2, 1]).set (title='Август');
sns.barplot(data=df_road_surf.query('month_of_year==9'), y='party_type', x='count', ax=axes[2, 2]).set (title='Сентябрь');
sns.barplot(data=df_road_surf.query('month_of_year==10'), y='party_type', x='count', ax=axes[3, 0]).set (title='Октябрь');
sns.barplot(data=df_road_surf.query('month_of_year==11'), y='party_type', x='count', ax=axes[3, 1]).set (title='Ноябрь');
sns.barplot(data=df_road_surf.query('month_of_year==12'), y='party_type', x='count', ax=axes[3, 2]).set (title='Декабрь');

# %% [markdown]
# **Вывод:** В первую очередь, наибольшее количество ДТП на обледенелой дороге встречается с ноября по апрель, что логично.
# Основными типами участников столкновений являются другие автомобили. Следующими по популярности являются дорожные знаки. Столновения со зданиями, отбойником и всем остальным встречается гораздо реже.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Отлично получилось!
# </div>

# %% [markdown]
# #### Задача 4. Страховки и типы авто. С графиком.

# %% [markdown]
# Оценим среднее значение суммы страховки в зависимости от возраста автомобиля. Страховка insurance_premium находится в таблице parties. Возраст автомобиля vehicle age указан в таблице vehicles.

# %%
# запрос

query_df_insu = '''
SELECT v.vehicle_age AS v_age,
       COUNT(v.vehicle_age) AS count,
       AVG(p.insurance_premium)
FROM parties AS p 
JOIN vehicles AS v ON p.case_id=v.case_id
GROUP BY v.vehicle_age
ORDER BY v.vehicle_age;
'''

df_insu = pd.read_sql_query(query_df_insu, con=engine)
df_insu
# Out:
#     v_age   count        avg
# 0     0.0   89759  35.491549
# 1     1.0   91383  36.625350
# 2     2.0  222730  32.263109
# 3     3.0  369722  31.117358
# 4     4.0  268330  34.087665
# 5     5.0  228606  37.079805
# 6     6.0  184367  39.896190
# 7     7.0  183937  42.389753
# 8     8.0  168048  44.883926
# 9     9.0  126711  47.659962
# 10   10.0   83530  50.215312
# 11   11.0   58912  53.080303
# 12   12.0   32216  55.896548
# 13   13.0   21833  58.250449
# 14   14.0    8788  59.275829
# 15   15.0    1480  59.096542
# 16   16.0     205  47.345550
# 17   17.0      70  40.924242
# 18   18.0       3  49.666667
# 19   19.0      14  39.714286
# 20   20.0       4  28.500000
# 21  161.0      33  32.600000
# 22    NaN       0  37.924397

# %%
# график

plt.rcParams['figure.figsize'] = [12, 8]
sns.barplot(data=df_insu, x='v_age', y='avg')
plt.title('Сравнение средней страховой выплаты в зависимости от возраста авто')
plt.xlabel('Возраст автомобиля, годы')
plt.ylabel('Средняя страховая выплата, тыс.дол.')
plt.show()

# %% [markdown]
# **Вывод:** максимальные средние значения страховых выплат приходятся на автомобили в возрасте 14-15 лет. Минимальные значения выплаты - для авто возрастом менее 5 лет и старше 20 лет.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Но insurance_premium это не выплата, а страховая премия — англ. Insurance Premium, является денежной суммой, взимаемой страховой компанией с целью активного покрытия потенциальных убытков. То есть это стоимость страховки
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> И я все равно не очень понимаю, кто кому ее платит. Клиент владельцу? Владелец страховой компании? В общем, я этот параметр использовала ради примера задачи с агрегирующей функцией.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Клиент покупает страховку у страховой компании, в РФ тоже есть такое, например ОСАГО, КАСКО, можно купить дополнительную расширенную страховку, что бы увеличить покрытие. Страховку покупают как непосредственно у страховой компании, так и через посредников, в том числе таким посредником может быть каршеринговая компания. Какая то базовая страховка может быть вклюсчена в цену аренды авто, можно докупить какие то расширения
# </div>

# %% [markdown]
# #### Задача 5. Влияние мобильного телефона на вину участника

# %% [markdown]
# Проверим, как повлияла на вину участников ДТП возможность или невозможность разговаривать по громкой связи по телефону в разрезе дополнительных участников ДТП. Например, с кем столкнулись виновные участники ДТП, которые не могли использовать громкую связь в телефоне.

# %%
# запрос

query_df_phone = '''
SELECT c.motor_vehicle_involved_with AS another_object,
COUNT (c.case_id)
FROM collisions AS c 
JOIN parties AS p ON c.case_id = p.case_id
WHERE p.at_fault = 0
AND p.cellphone_in_use = 1
GROUP BY c.motor_vehicle_involved_with
ORDER BY count DESC;
'''

df_phone = pd.read_sql_query(query_df_phone, con=engine)
df_phone
# Out:
#                    another_object  count
# 0             other motor vehicle  17709
# 1                    other object   1082
# 2            parked motor vehicle    673
# 3                    fixed object    557
# 4                         bicycle    498
# 5  motor vehicle on other roadway    202
# 6                   non-collision    193
# 7                          animal     73
# 8                            None     65
# 9                           train      1

# %%
# изменим запрос, если участник оказался невиновным

query_df_phone_2 = '''
SELECT c.motor_vehicle_involved_with AS another_object,
COUNT (c.case_id)
FROM collisions AS c 
JOIN parties AS p ON c.case_id = p.case_id
WHERE p.at_fault = 1
AND p.cellphone_in_use = 1
GROUP BY c.motor_vehicle_involved_with
ORDER BY count DESC;
'''

df_phone_2 = pd.read_sql_query(query_df_phone_2, con=engine)
df_phone_2
# Out:
#                    another_object  count
# 0             other motor vehicle  15956
# 1                    fixed object   4577
# 2            parked motor vehicle   1922
# 3                    other object    992
# 4                   non-collision    605
# 5                         bicycle    440
# 6  motor vehicle on other roadway    181
# 7                            None     77
# 8                          animal     12
# 9                           train     10

# %%
# изменим запрос, если участник оказался виновным, и не мог использовать громкую связь

query_df_phone_3 = '''
SELECT c.motor_vehicle_involved_with AS another_object,
COUNT (c.case_id)
FROM collisions AS c 
JOIN parties AS p ON c.case_id = p.case_id
WHERE p.at_fault = 0
AND p.cellphone_in_use = 0
GROUP BY c.motor_vehicle_involved_with
ORDER BY count DESC;
'''

df_phone_3 = pd.read_sql_query(query_df_phone_3, con=engine)
df_phone_3
# Out:
#                    another_object   count
# 0             other motor vehicle  958743
# 1            parked motor vehicle   59296
# 2                    other object   49813
# 3                         bicycle   33226
# 4                    fixed object   25452
# 5                   non-collision   10542
# 6  motor vehicle on other roadway    9889
# 7                          animal    5469
# 8                            None    3239
# 9                           train     263

# %% [markdown]
# Существенно выросло количество ДТП. А приоритетные цели практически не изменились.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# #### Задача 6. Город ДТП и наличие алгоколя в крови.

# %% [markdown]
# Посчитаем, сколько ДТП происходило с нетрезвыми водителями в различных городах.

# %%
# запрос

query_df_city = '''
SELECT c.county_location,
       COUNT (c.case_id)
FROM collisions AS c 
JOIN parties AS p ON c.case_id = p.case_id
WHERE p.party_sobriety LIKE 'had been drinking%%'
GROUP BY c.county_location 
ORDER BY count DESC;   
'''

df_city = pd.read_sql_query(query_df_city, con=engine)
df_city
# Out:
#     county_location  count
# 0       los angeles  40725
# 1            orange  13107
# 2         san diego  10870
# 3    san bernardino   8585
# 4         riverside   8182
# 5           alameda   5716
# 6        sacramento   5544
# 7       santa clara   4874
# 8              kern   3887
# 9           ventura   3614
# 10           fresno   3599
# 11     contra costa   3484
# 12      san joaquin   2922
# 13        san mateo   2794
# 14       stanislaus   2513
# 15    san francisco   2416
# 16    santa barbara   2339
# 17           sonoma   2327
# 18           tulare   2083
# 19         monterey   1984
# 20           solano   1587
# 21  san luis obispo   1468
# 22       santa cruz   1466
# 23           placer   1218
# 24           merced   1210
# 25            butte   1115
# 26         humboldt    946
# 27            marin    937
# 28        el dorado    920
# 29           shasta    894
# 30             yolo    804
# 31           madera    803
# 32             napa    745
# ...

# %% [markdown]
# ## Четвертый этап. Создание модели для оценки водительского риска

# %% [markdown]
# ### Отбор данных на основе первичного предположения заказчика

# %% [markdown]
# Напомним, как звучали условия отбора данных от заказчика:
# - тип виновника ДТП - только car.
# - выбираем только те ДТП, когда оно привело к любым значимым повреждениям автомобиля любого из участников — все, кроме типа SCRATCH (царапина).
# - выбираем данные только за 2012 год.
# - обязательно учитываем возраст автомобиля.

# %%
# отберем данные

query_df_2012_f = '''
SELECT *
FROM collisions AS c 
RIGHT OUTER JOIN parties AS p ON c.case_id=p.case_id 
RIGHT OUTER JOIN vehicles AS v ON p.case_id=v.case_id AND p.party_number = v.party_number

WHERE EXTRACT(YEAR FROM c.collision_date)::int = 2012
AND c.collision_damage != 'scratch'
AND p.party_type = 'car';
'''

pd.set_option('display.max_columns', None)


df_2012_f = pd.read_sql_query(query_df_2012_f, con=engine)
df_2012_f.head()
# Out:
#    case_id county_city_location county_location  distance direction  \
# 0  5600850                 5604         ventura     150.0     north
# 1  5600893                 2908          nevada     190.0      east
# 2  5603123                 1600           kings    2640.0      east
# 3  5455644                 4806          solano     350.0     south
# 4  5455680                 3001          orange       0.0      None
#
#    intersection weather_1 location_type collision_damage  party_count  \
# 0           0.0     clear       highway     small damage            2
# 1           0.0     clear          None     small damage            1
# 2           0.0    cloudy       highway     small damage            2
# 3           0.0    cloudy          ramp     small damage            3
# 4           1.0     clear          None     small damage            3
#
#   primary_collision_factor   pcf_violation_category type_of_collision  \
# ...

# %%
# оценим размер получившейся выборки

df_2012_f.shape
# Out:
# (56248, 35)

# %%
# проверим, что у нас попали оба участника ДТП

df_2012_f.query('case_id == "5608413"')
# Out:
#        case_id county_city_location county_location  distance direction  \
# 6043   5608413                 2002          madera       0.0      None
# 23315  5608413                 2002          madera       0.0      None
#
#        intersection weather_1 location_type collision_damage  party_count  \
# 6043            1.0      None          None    middle damage            2
# 23315           1.0      None          None    middle damage            2
#
#       primary_collision_factor   pcf_violation_category type_of_collision  \
# 6043    vehicle code violation  automobile right of way         broadside
# 23315   vehicle code violation  automobile right of way         broadside
#
#       motor_vehicle_involved_with road_surface road_condition_1 lighting  \
# 6043          other motor vehicle         None             None     None
# 23315         other motor vehicle         None             None     None
#
#       control_device collision_date collision_time       id  case_id  \
# ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Давай попробуем отобрать через INNER JOIN.

# %%
# отберем данные

query_df_2012 = '''
SELECT *
FROM collisions AS c 
INNER JOIN parties AS p ON c.case_id=p.case_id 
INNER JOIN vehicles AS v ON p.case_id=v.case_id AND p.party_number = v.party_number

WHERE EXTRACT(YEAR FROM c.collision_date)::int = 2012
AND c.collision_damage != 'scratch'
AND p.party_type = 'car';
'''

pd.set_option('display.max_columns', None)


df_2012 = pd.read_sql_query(query_df_2012, con=engine)
df_2012.head()
# Out:
#    case_id county_city_location county_location  distance direction  \
# 0  5449062                 0708    contra costa      21.0      east
# 1  5600850                 5604         ventura     150.0     north
# 2  5600893                 2908          nevada     190.0      east
# 3  5603123                 1600           kings    2640.0      east
# 4  5455644                 4806          solano     350.0     south
#
#    intersection weather_1 location_type collision_damage  party_count  \
# 0           0.0     clear          None     small damage            2
# 1           0.0     clear       highway     small damage            2
# 2           0.0     clear          None     small damage            1
# 3           0.0    cloudy       highway     small damage            2
# 4           0.0    cloudy          ramp     small damage            3
#
#   primary_collision_factor pcf_violation_category type_of_collision  \
# ...

# %%
# оценим размер получившейся выборки

df_2012.shape
# Out:
# (56248, 35)

# %%
# проверим, что у нас попали оба участника ДТП

df_2012.query('case_id == "5608413"')
# Out:
#        case_id county_city_location county_location  distance direction  \
# 4807   5608413                 2002          madera       0.0      None
# 18682  5608413                 2002          madera       0.0      None
#
#        intersection weather_1 location_type collision_damage  party_count  \
# 4807            1.0      None          None    middle damage            2
# 18682           1.0      None          None    middle damage            2
#
#       primary_collision_factor   pcf_violation_category type_of_collision  \
# 4807    vehicle code violation  automobile right of way         broadside
# 18682   vehicle code violation  automobile right of way         broadside
#
#       motor_vehicle_involved_with road_surface road_condition_1 lighting  \
# 4807          other motor vehicle         None             None     None
# 18682         other motor vehicle         None             None     None
#
#       control_device collision_date collision_time       id  case_id  \
# ...

# %% [markdown]
# Что же, количество строк в выгрузках совпадает. В обоих запросах участвуют оба участника проверочного ДТП. Отличаются индексами строк из объединенного датафрейма.

# %% [markdown]
# ### Первичный отбор параметров

# %% [markdown]
# По условию проекта предполагается произвести отбор параметров, исходя из их **описания**. ~~А проводить исследовательский анализ уже после отбора факторов. Звучит несколько странно, ибо зачем гадать, если можно точно проверить? Но, предположим, что нам не хватит оперативной памяти, чтобы узнать коэффициенты корреляции Фи для 35 колонок и 56248 строк. Итак, посмотрим на полученные колонки.~~

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Дело не в корреляции, нужно отобрать те факторы, которые мы сможем использовать (а после исследования уже может быть принято решение, что и эти признаки использовать не стоит). Отбирать их нужно не из 56248, а зи БД, то есть в запросы использовать не *, а конкретные признаки. Это не гадание, это осознанный отбор нужных полей исходя их смысла задачи.
# </div>

# %%
df_2012.columns
# Out:
# Index(['case_id', 'county_city_location', 'county_location', 'distance',
#        'direction', 'intersection', 'weather_1', 'location_type',
#        'collision_damage', 'party_count', 'primary_collision_factor',
#        'pcf_violation_category', 'type_of_collision',
#        'motor_vehicle_involved_with', 'road_surface', 'road_condition_1',
#        'lighting', 'control_device', 'collision_date', 'collision_time', 'id',
#        'case_id', 'party_number', 'party_type', 'at_fault',
#        'insurance_premium', 'party_sobriety', 'party_drug_physical',
#        'cellphone_in_use', 'id', 'case_id', 'party_number', 'vehicle_type',
#        'vehicle_transmission', 'vehicle_age'],
#       dtype='object')

# %% [markdown]
# **Признаки, которые могут быть полезны для модели:**
# ~~- `case id` - одна такая колонка нам точно необходима;~~
# - `county location` - пригодится. Не думаю, что заказчик работает в одном городе и сдает машины для поездок в пределах одного города.
# - `distance` - расстояние от главной дороги - пока оставим.
# - `wheather 1` - безусловно, оставляем. Погодные условия - это важно.
# ~~- `collision damage` - ущерб от аварии. Полагаю, это важный признак.~~
# - `direction` - направление движения. Описывает предполагаемый маршрут.
# ~~- `party count` - количество участников. Сомнительно, но пусть пока будет. Предполагается, что заказчик сдает автомобиль одному клиенту. А уж со сколькими он мог гипотетически столкнуться - есть ли разница для владельца машины? Разве что ущерб может быть больше, если участников больше.~~
# ~~- `primary collision factor` - основной фактор аварии - оставим, если это будет определяться из маршрута.~~
# ~~- `pcf violation category` - категория нарушения. Пока оставим, возможно, он будет коррелировать с другими признаками.~~
# ~~- `type of collision` - тип аварии - оставляем.~~
# ~~- `motor vehicle involved with` - оставляем. Мне интересна статистика, и я считаю параметр полезным для модели.~~
# - `road surface` - состояние дороги. Может быть важным признаком.
# - `road condition 1` - состояние дорожного покрытия - оставим, но большая часть наблюдений относится к совершенно нормальному дорожному покрытию.
# - `lighting` - освещенность - оставляем, считаю это важным.
# - `collision date` - полагаю, может быть полезным.
# - `collision time` - полагаю, может быть полезным.
# - `intersection` - является ли место ДТП перекрестком. Вряд ли бывают дороги совершенно без перекрестков, но он может характеризовать маршрут.
# - `location type` - тип дороги. В данном параметре очень много пропусков, и опять же - это дорога, но он может характеризовать маршрут.
# ~~- `party number` - пока оставим, пока неясно, важно ли это.~~
# - `at fault` - Обязательно, это наш целевой признак.
# - `insurance premium` - пока оставим, пока неясно, важно ли это.
# ~~- `party sobriety` - обязательно оставляем.~~
# ~~- `party drug physical` - в данных очень много пропусков, но они могут быть полезны модели.~~
# - `cellphone in use` - полагаю, признак малозначимый ввиду разделения значений в нем (2 млн 149 тысяч "да" против 45 тысяч "нет").
# - `vehicle type` - тип кузова авто. Известны заранее.
# - `vehicle transmission` - тип коробки передач. Известны заранее.
# - `vehicle age` - оставляем, ибо такого требование заказчика.
#
#
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> case id не нужен, по нему происходит объединение, но сам признак не пригодинтся при обучении модели
# </div>
#
#
#
# **Признаки, от которых можно избавиться:**
# - `case id` - используется только для объединения;
# - `county city location` - для географического признака достаточно одной колонки, и пусть это будет колонка с городом.
# - `collision damage` - ущерб от аварии. Не можем использовать, так как он описывает последствия аварии.
# ~~- `direction` - направление движения. Не вижу смысла в этом признаке. Данных в нем распределено примерно поровну.~~
# - `primary collision factor` - основной фактор аварии - описывает последствия.
# - `pcf violation category` - категория нарушения. Описывает последствия.
# - `type of collision` - тип аварии - описывает последствия.
# - `motor vehicle involved with` - оставляем. Описывает последствия.
# - `party number` - используется только для объединения.
# - `party count` - количество участников. Описывает последствия.
# - `party sobriety` - не можем использовать, так как заказчик не может заранее получить эти данные.
# - `party drug physical` - не можем использовать, так как заказчик не может заранее получить эти данные.
# ~~- `intersection` - является ли место ДТП перекрестком. Вряд ли бывают дороги совершенно без перекрестков.~~
# ~~- `location type` - тип дороги. В данном параметре очень много пропусков, и опять же - это дорога, какая бы она не была.~~
# - `control device` - даже немного неясно, о чем этот параметр. Но он находится в таблице collisions, а значит, с большой долей вероятности, не может быть известен заказчику.
# - `id` - не нужен, мы объединяли таблицы по case id.
# - `case id` - дублирующие колонки необходимо убрать.
# - `party type` - мы сделали отбор таким образом, что у нас остались только машины-участники ДТП.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не придумала способа, как удалить дублирующие колонки, по которым шло объединение. Предлагается в теории по SQL только вытащить при объединении нужные колонки.

# %% [markdown]
# <div class="alert alert-danger">
# <s><b>😔 Необходимо исправить:</b> Да, нужно отбирать только те признаки, которые нам нужны. Для обучения модели можно использовать только те признаки, которые известны до начала поездки, признаки описывающие само ДТП не долдны использоваться при обучении модели, то есть они не должны отбираться в запросе. Нам нужны максимально полные данне, поэтому тип объединения здесь INNER</s>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Светлана, не могу пока согласиться по типу объединения. Таблица collision, которую я выбираю основой для присоединения, содержит 1 400 000 записей, и case id там уникальны. Она описывает каждый случай зафиксированного ДТП.
#
# Далее, я начинаю присоединять к ней данные из таблицы parties, которая состоит из 2 752 407 записей, и case id там не уникальны, а встречаются столько раз, сколько участников было у ДТП с таким уникальным case id. И когда я присоединяю эту таблицу, я хочу, чтобы ВСЕ строки с уникальным case id из таблицы collisions попали в общую таблицу из таблицы parties. Поэтому я выбираю RIGHT OUTER JOIN. И, соотвественно, аналогично поступаю с таблицей vehicles, которая состоит из 1 021 234 записей. Забираю из нее (т.е. правой таблицы) ВСЕ записи, которые совпадут с таблицей parties по case id и party number.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Но при этом, если каких-то case id не будет в таблицах collision или parties, то будет получено много пропусков, и смысла в этих строках не будет. Здесь количество строк совпадает просто потому, что нам повезло с данными
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ох, давай еще порассуждаем, какие-же признаки мы можем использовать и почему. Это прям очень серьезный и болезненный вопрос в этом проекте.
#
# С одной стороны, нам нужны признаки, которые гипотетически мог бы получить заказчик:
#
# ![image.png](attachment:image.png)
#
# С другой стороны, в задании есть такая фраза, что:
#
# ![image-2.png](attachment:image-2.png)
#
# В моем понимании, "исторические данные" - это все факторы, что известны про случившиеся ДТП.
#
# Я прочла справку по каршеринговым сервисам в США. В большинстве своем, они не предполагают прямого взаимодействия клиента и менеджера. Клиент регистрируется в сервисе, при необходимости - находит авто, садится и едет. Бывает, что сервис работает в пределах одного города, но у нас нет точной информации, в какому типу относится наш. И я не встречала информации, что может быть ограничен маршрут для клиента. В общем, как я понимаю, владелец бизнеса может знать о том: в какой день клиент арендовал авто, какое именно авто (т.е. тип кузова, коробки передач, года выпуска). Раз нам предлагают оценить маршрут, то может знать расстояние от главной дороги, направление движения, всю информацию о состоянии дороги. Допустим, даже можем взять информацию о том, есть ли на маршруте перекрестки (все таки в США много прямых шоссе). Но владелец не может точно знать состояние клиента (трезв ли он или под воздействием чего либо), не может знать, сколько персон едет в авто. Не может быть уверен относительно погоды, на самом деле. Относительно времени - тоже спорная штука. Мы же не предполагем, что клиент прямо сразу впишется в кого-либо. Непонятный признак control device. И насчет страховой выплаты я тоже не очень понимаю - кому и кем она выплачивается.
#
# А что касается "исторических данных" - тут как раз будет стастика ДТП с водителями под воздействием алкоголя, наркотиков, лекарств. Раз наш владелец бизнеса не может получить эту информацию на текущем этапе его организации, значит, мы не можем ее включать в модель. Как же мы тогда узнаем, насколько этот признак важен?

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Исторические данные всегда более полные, у нас есть понимание того, какие факторы могут быть известны заранее6 а какие нет. У нас есть условие "клиент выбрал маршрут", то есть эти данные передадутся в каршеринговую компанию и мы узнаем куда поедет клиент, сможем построить маршрут (возможно предложить клиенту более безопасный), при построении маршрута легко считаются и перекрестки, и виды дорог и многие другие факторы. Про состояние водителя данные спорные, здесь можно рассуждать, что мы не знаем и не включать эти данные (нормальный вариант, то есть это твое решение, можно исключить), можно порассуждать, что в мире уже созданы и внедрены различные системы, которые позволяют оценивать состояние водителя (то есть и оставить их можно, предположив, что наша компания высокотехнологичная и внедряет такие вещи, но повторюсь, это твое решение, любой вариант по признакам состояния водителя будет верным, так как заказчик не уточнил конкретно и мы можем сами об этом подумать и решить). Сколько персон едет в авто мы не знаем, таких данных нет в датасете, даже исторических. Если мы не можем включать какие то признаки в модель, то зачем нам их важность? Модель обученная на них будет бесполезна и не решит задачу заказчика. Пока не будет изобретена машина времени признаки из будущего не могут быть важны при обучении модели, поэтому их нужно отбрасывать.
#
# nsurance Premium, является денежной суммой, взимаемой страховой компанией с целью активного покрытия потенциальных убытков. То есть это стоимость страховки, она известна до поездки, страховка точно покупается до поездки.
#
#
# control device - описывает автомобиль, то есть мы знаем ДО поездки есть он или нет. Как раз об его использовании стоит принять решение после исследования. case_id не нужен. То есть алгоритм такое - отбираем только те признаки, которые могут быть известны до поездки (все, что описывает ДТП кроме даты и времени, не берем, case_id не берем, это просто номер и никак не связан с аварийностю), все остальные признаки берем (сорстояние водителя на твое усмотрение, можно тоже сразу отбросить). Потом эти признаки исследуются, происходит заполнение пропусков или удаление строк с пропусками, корреляционный анализ и после этого принисаетя решение какие из отобранных признаков в итогу будет отобраны для обучения модели. Какие то гакажутся невежными6 в каких то будет огромное количество пропусков и они будут бесполезны.
#
# party_number Нельзя использовать, он описывает ДТП.
#
# В
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я использовала эти два поля, поскольку по ним производила объединение. Я не знала, что можно не выводить их в результат. Перед обучением модели я эти поля удалила. А до - проверяла по ним корректность объединения данных.
#
# Признак control device находится в таблице collisions. Она больше ДТП описывает, нежели авто. Если бы он был в таблице vehicles - взяла бы в модель. Раз мы не можем уточнить у заказчика, что точно означает этот признак, мне будет спокойнее, если я не буду его использовать.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Да, его можно не использовать. Не обязательно выводить те полля, по которым проводится объединение или фильтрация в SQL
# </div>

# %%
query_for_model = '''
SELECT c.county_location,
       c.distance,
       c.weather_1,
       c.direction,
       c.road_surface, 
       c.road_condition_1,
       c.intersection,
       c.location_type,
       c.lighting, 
       c.collision_date,
       c.collision_time,
       p.at_fault,
       p.insurance_premium,
       p.cellphone_in_use, 
       v.vehicle_type,
       v.vehicle_transmission,
       v.vehicle_age

FROM collisions AS c 
INNER JOIN parties AS p ON c.case_id=p.case_id 
INNER JOIN vehicles AS v ON p.case_id=v.case_id AND p.party_number = v.party_number

WHERE (EXTRACT(YEAR FROM c.collision_date)::int = 2012)
AND (c.collision_damage <> 'scratch')
AND (p.party_type = 'car');
'''

df_for_model = pd.read_sql_query(query_for_model, con=engine)
                        
df_for_model.shape
# Out:
# (56248, 17)

# %% [markdown]
# ### Предобработка выборки

# %%
df_for_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56248 entries, 0 to 56247
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   county_location       56248 non-null  object
#  1   distance              56248 non-null  float64
#  2   weather_1             56080 non-null  object
#  3   direction             43230 non-null  object
#  4   road_surface          55900 non-null  object
#  5   road_condition_1      55999 non-null  object
#  6   intersection          56073 non-null  float64
#  7   location_type         25932 non-null  object
#  8   lighting              56094 non-null  object
#  9   collision_date        56248 non-null  object
#  10  collision_time        56160 non-null  object
#  11  at_fault              56248 non-null  int64
#  12  insurance_premium     55701 non-null  float64
#  13  cellphone_in_use      51777 non-null  float64
#  14  vehicle_type          56248 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.1</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не преобразовались данные из даты и времени аварии через CAST. Возможно, из-за значений `None` в строках.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# И формат объектный, и пропуски есть во времени.

# %%
# формат даты год-месяц-день

df_for_model['collision_date'].sample(5)
# Out:
# 4884     2012-03-10
# 37633    2012-04-11
# 19322    2012-05-11
# 16975    2012-01-08
# 23346    2012-02-17
# Name: collision_date, dtype: object

# %%
# формат времени час-минуты-секунды

df_for_model['collision_time'].sample(5)
# Out:
# 23076    10:30:00
# 33543    09:05:00
# 16693    18:30:00
# 15325    08:50:00
# 46642    16:55:00
# Name: collision_time, dtype: object

# %%
# посмотрим, что с пропущенным временем

null_values = df_for_model[df_for_model['collision_time'].isnull()]
null_values.sample(2)
# Out:
#       county_location  distance weather_1 direction road_surface  \
# 47757        monterey    1091.0     clear      east          dry
# 50774       mendocino    3696.0     clear     south          dry
#
#       road_condition_1  intersection location_type  \
# 47757           normal           0.0       highway
# 50774           normal           0.0       highway
#
#                          lighting collision_date collision_time  at_fault  \
# 47757  dark with no street lights     2012-02-05           None         1
# 50774  dark with no street lights     2012-08-08           None         1
#
#        insurance_premium  cellphone_in_use vehicle_type vehicle_transmission  \
# 47757               24.0               0.0        coupe               manual
# 50774               38.0               0.0        coupe               manual
#
#        vehicle_age
# 47757          3.0
# 50774          6.0

# %%
# посмотрим на заполненные значения в этой колонке

df_for_model['collision_time'].value_counts()
# Out:
# 15:00:00    413
# 15:30:00    362
# 16:00:00    342
# 18:00:00    317
# 15:20:00    302
#            ...
# 03:16:00      1
# 05:23:00      1
# 04:27:00      1
# 06:23:00      1
# 04:04:00      1
# Name: collision_time, Length: 1435, dtype: int64

# %% [markdown]
# Заполним пропуски наиболее частым временем.

# %%
#import datetime

# %%
# Заполним их

#df_for_model['collision_time'] = df_for_model['collision_time'].astype('str')

#df_for_model['collision_time'].fillna('15:00:00')
#КОД РЕВЬЮЕРА
df_for_model['collision_time'] = df_for_model['collision_time'].fillna(datetime.time(15, 00))
df_for_model['collision_time'].value_counts()
# Out:
# 15:00:00    501
# 15:30:00    362
# 16:00:00    342
# 18:00:00    317
# 15:20:00    302
#            ...
# 03:16:00      1
# 05:23:00      1
# 04:27:00      1
# 06:23:00      1
# 04:04:00      1
# Name: collision_time, Length: 1435, dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> При переводе типа данных в строку пропусков не осталось, они были заменены на None, то есть при выполнении fillna() заполнять было уже нечего. Всегда стоит импортировать библиотеку для работы с датой и временем (я добавила ее здесь, что бы ты обратила внимание, а так все импорты должны быть в первой ячейке), я показала как заполнить пропуски, код ниже уже не нужен
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Перенесла импорт библиотеки в начало. Я с ней ранее не работала.

# %% [markdown]
# ~~Так, мое значение в 15 часов добавилось к перечню уникальных значений, но не объединилось с исходными 15 часами. Поищем иные значения, которые не соответствуют формату времени.~~

# %%
#df_for_model['collision_time'].tolist()

# %%
# заменяем значение

# df_for_model['collision_time'] = df_for_model['collision_time'].str.replace('None', '15:00:00')

# df_for_model['collision_time'].value_counts()

# %% [markdown]
# Пропуски и None обработали. Теперь соберем две эти колонки вместе, и переведем в формат datetime.

# %%
# Объединим эти колонки

df_for_model['collision_datetime'] = \
            df_for_model['collision_date'].astype('str') + ' ' + df_for_model['collision_time'].astype('str')

# %%
# преобразуем полученный признак

df_for_model['collision_datetime'] = pd.to_datetime(df_for_model['collision_datetime'], format='%Y-%m-%d %H:%M:%S')

df_for_model['collision_datetime'].sample()
# Out:
# 19353   2012-05-02 11:40:00
# Name: collision_datetime, dtype: datetime64[ns]

# %%
# проверим формат данных

df_for_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56248 entries, 0 to 56247
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   county_location       56248 non-null  object
#  1   distance              56248 non-null  float64
#  2   weather_1             56080 non-null  object
#  3   direction             43230 non-null  object
#  4   road_surface          55900 non-null  object
#  5   road_condition_1      55999 non-null  object
#  6   intersection          56073 non-null  float64
#  7   location_type         25932 non-null  object
#  8   lighting              56094 non-null  object
#  9   collision_date        56248 non-null  object
#  10  collision_time        56248 non-null  object
#  11  at_fault              56248 non-null  int64
#  12  insurance_premium     55701 non-null  float64
#  13  cellphone_in_use      51777 non-null  float64
#  14  vehicle_type          56248 non-null  object
# ...

# %%
# проверим на пропуски наши данные

df_for_model.isna().mean()*100
# Out:
# county_location          0.000000
# distance                 0.000000
# weather_1                0.298677
# direction               23.143934
# road_surface             0.618689
# road_condition_1         0.442682
# intersection             0.311122
# location_type           53.897027
# lighting                 0.273788
# collision_date           0.000000
# collision_time           0.000000
# at_fault                 0.000000
# insurance_premium        0.972479
# cellphone_in_use         7.948727
# vehicle_type             0.000000
# vehicle_transmission     1.527165
# vehicle_age              3.011663
# collision_datetime       0.000000
# dtype: float64

# %% [markdown]
# Большая часть пропущенных данных относится к объектному типу. Причем, в значениях многих параметров уже фигурирует вариант `unknown`, так что можно использовать его для заполнения пропусков.
#
# Что касается количественных параметров: страховая выплата и возраст авто. А также "возможность использовать громкую связь".
# - С некоторым допущением можно заполнить пропуски страховой выплаты нулем;
# - Поскольку параметр "возраст авто" важен для заказчика, то пропущенные и "161 год" можно удалить из данных;
# - Считаю, что параметр "возможность использовать громкую связь" отнести его к категориальным признакам.
#
#
# Обозначенные замены в пропущенных категориальных данных можно реализовать в шаге предобработки в пайплайне.
# А избавиться от некорректных строк с количественными параметрами, которые невозможно корректно заполнить, можно уже сейчас.

# %%
# переведем тип данных в колонке "телефон" и "перекресток" в целочисленный

df_for_model[['cellphone_in_use', 'intersection']] = df_for_model[['cellphone_in_use', 'intersection']].fillna(0)
df_for_model[['cellphone_in_use', 'intersection']] = df_for_model[['cellphone_in_use', 'intersection']].astype('int')

# %%
# удалим строки с пропущенным возрастом авто

df_for_model = df_for_model.dropna(axis=0, subset=['vehicle_age'])
df_for_model.shape
# Out:
# (54554, 18)

# %%
# удалим строки с возрастом 161 год

df_for_model = df_for_model.loc[df_for_model['vehicle_age']< 21]
df_for_model.shape
# Out:
# (54552, 18)

# %%
# заполним пропуски в сумме страховки нулем

df_for_model['insurance_premium'] = df_for_model['insurance_premium'].fillna(0)

# %%
df_for_model.isna().mean()*100
# Out:
# county_location          0.000000
# distance                 0.000000
# weather_1                0.302464
# direction               22.833260
# road_surface             0.603094
# road_condition_1         0.434448
# intersection             0.000000
# location_type           53.237278
# lighting                 0.278633
# collision_date           0.000000
# collision_time           0.000000
# at_fault                 0.000000
# insurance_premium        0.000000
# cellphone_in_use         0.000000
# vehicle_type             0.000000
# vehicle_transmission     1.054040
# vehicle_age              0.000000
# collision_datetime       0.000000
# dtype: float64

# %% [markdown]
# Остальные пропуски относятся к категорийным данным.

# %%
# добавим колонку с месяцем

df_for_model['month'] = pd.DatetimeIndex(df_for_model['collision_datetime']).month

# %%
# выведем колонку с часом суток

df_for_model['hour'] = pd.DatetimeIndex(df_for_model['collision_datetime']).hour

# %%
# составим функцию для классификации времени суток

def collision_hour(hour):
    try:
        if 6 <= hour < 11:
            return 'morning'
        elif 11 <= hour < 17:
            return 'afternoon'
        elif 17 <= hour < 22:
            return 'evening'
        elif 22 <= hour < 24:
            return 'night'
        elif 0 <= hour < 6:
            return 'night'
    except:
        pass

# %%
# внесем параметр времени суток для аварий

df_for_model['part_of_day'] = df_for_model['hour'].apply(collision_hour)

df_for_model.sample(4)
# Out:
#       county_location  distance weather_1 direction road_surface  \
# 31847     los angeles     100.0     clear     north          dry
# 35722          orange     400.0     clear     south          dry
# 48559     los angeles     120.0     clear     south          dry
# 29887        humboldt       0.0     clear      None          dry
#
#       road_condition_1  intersection location_type                 lighting  \
# 31847           normal             0       highway                 daylight
# 35722     construction             0       highway                 daylight
# 48559           normal             0          None  dark with street lights
# 29887           normal             1          None                 daylight
#
#       collision_date collision_time  at_fault  insurance_premium  \
# 31847     2012-03-15       13:40:00         0               71.0
# 35722     2012-05-05       14:34:00         1               46.0
# ...

# %%
# проверим еще раз пропуски

df_for_model.isna().mean()*100
# Out:
# county_location          0.000000
# distance                 0.000000
# weather_1                0.302464
# direction               22.833260
# road_surface             0.603094
# road_condition_1         0.434448
# intersection             0.000000
# location_type           53.237278
# lighting                 0.278633
# collision_date           0.000000
# collision_time           0.000000
# at_fault                 0.000000
# insurance_premium        0.000000
# cellphone_in_use         0.000000
# vehicle_type             0.000000
# vehicle_transmission     1.054040
# vehicle_age              0.000000
# collision_datetime       0.000000
# month                    0.000000
# hour                     0.000000
# part_of_day              0.000000
# dtype: float64

# %% [markdown]
# ### Исследовательский анализ выборки

# %% [markdown]
# Построим графики распределения каждого из признаков, и попробуем оценить их важность для модели.

# %%
sns.countplot(data=df_for_model, y='county_location')
plt.title('Сравнение частоты ДТП в 2012 году в разных городах')
plt.xlabel('Количество ДТП')
plt.ylabel('Город')
plt.show()

# %% [markdown]
# Много разных городов, есть лидеры по числу аварий.

# %%
sns.histplot(data=df_for_model.query('distance < 10000'), x='distance')
plt.title('Сравнение частоты ДТП в 2012 году на разных расстояниях от главной дороги')
plt.xlabel('Расстояние от главной дороги, м')
plt.ylabel('Количество ДТП')
plt.show()

# %% [markdown]
# А вот этот признак - очень неудобный. У нас есть выбросы в данных, и основные происшествия происходят на дорогах, где расстояние будет около нуля.

# %%
plt.rcdefaults()
sns.countplot(data=df_for_model, y='weather_1')
plt.title('Сравнение частоты ДТП в 2012 году от погодных условий')
plt.xlabel('Количество ДТП')
plt.ylabel('Погода')
plt.show()

# %% [markdown]
# Кажется, что данный признак практически не влияет на количество аварий.

# %%
sns.countplot(data=df_for_model, y='direction')
plt.title('Сравнение направлений движения в ДТП в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Направление движения')
plt.show()

# %%
sns.countplot(data=df_for_model, y='road_surface')
plt.title('Сравнение проблем в дорогой в ДТП в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Типы проблемы с дорогой')
plt.show()

# %%
sns.countplot(data=df_for_model, y='road_condition_1')
plt.title('Сравнение качества дорожного полотна в ДТП в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Качество дорожного полотна')
plt.show()

# %%
sns.countplot(data=df_for_model, y='intersection', hue='intersection')
plt.title('Сравнение количества ДТП на перекрестках в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Является ли перекрестком')
plt.legend(['не перекресток', 'перекресток'])
plt.show()

# %%
sns.countplot(data=df_for_model, y='location_type')
plt.title('Сравнение типов дорог в ДТП в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Тип дороги')
plt.show()

# %%
sns.countplot(data=df_for_model, y='lighting')
plt.title('Сравнение уровня освещенности в ДТП в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Уровень освещенности')
plt.show()

# %%
sns.countplot(data=df_for_model, y='at_fault', hue='at_fault')
plt.title('Сравнение признания виновным в ДТП в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Виновен или нет в ДТП')
plt.legend(labels=['не виновен','виновен'], bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не понимаю, почему не хочет в легенду оба значения разместить.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Для этого нужно добавить параметр hue
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Так получается некрасиво. График же начинает думать, что у нас в категории есть подкатегория. :(

# %%
plt.rcParams['figure.figsize'] = [12, 8]
sns.histplot(data=df_for_model, x='insurance_premium', bins= 100)
plt.title('Сравнение страховых выплат ДТП в 2012 году')
plt.xlabel('Страховая выплата, тыс. дол.')
plt.ylabel('Количество ДТП')
plt.show()

# %%
plt.rcdefaults()
sns.countplot(data=df_for_model, y='cellphone_in_use', hue='cellphone_in_use')
plt.title('Сравнение возможности использования громкой связи в авто в ДТП в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Может использовать громкую связь или нет')
plt.legend(['не может', 'может'])
plt.show()

# %%
sns.countplot(data=df_for_model, y='vehicle_type')
plt.title('Сравнение типов авто в ДТП в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Тип авто')
plt.show()

# %%
sns.countplot(data=df_for_model, y='vehicle_transmission')
plt.title('Сравнение типов коробки передач в ДТП в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Тип коробки передач авто')
plt.show()

# %%
sns.countplot(data=df_for_model, y='vehicle_age')
plt.title('Сравнение возраста авто в ДТП в 2012')
plt.xlabel('Количество ДТП')
plt.ylabel('Возраст авто')
plt.show()

# %%
sns.countplot(data=df_for_model, y='month')
plt.title('Сравнение количества ДТП в 2012 по месяцам')
plt.xlabel('Количество ДТП')
plt.ylabel('Месяц')
plt.show()

# %% [markdown]
# Какая-то неправдоподобная статистика. В целом, если смотреть по всему исходному датафрейму, аварии распределены примерно одинаково, и зимой их несколько больше. Здесь же начиная с июля, ДТП практически отсутствуют. Не уверена, что можно получить достоверную модель на таких данных.
#
# Могла ли произойти ошибка при чтении даты?

# %%
sns.countplot(data=df_for_model, y='part_of_day')
plt.title('Сравнение количества ДТП в 2012 по времени дня')
plt.xlabel('Количество ДТП')
plt.ylabel('Время суток')
plt.show()

# %% [markdown]
# ### Подготовка данных для модели

# %% [markdown]
# Я много размышляла над постановкой задачи. И все еще не уверена, что верно понимаю путь ее решения.
#
# ~~Мне не дают покоя колонки `case id` и `party number`. По сути, наши данные разделяются на, условно, кластеры, соответствующие каждому уникальному номеру ДТП. И количество участников относится к каждому отдельному ДТП. ~~
#
# ~~Я не вижу причин, чтобы модель для поиска "виновного" использовала эти колонки. И я не представляю, как разделить данные на кластеры по номеру ДТП, и обучать поиску "виноватого" внутри кластера.~~
#
# И вообще, наша задача - предсказать, какова вероятность, что клиент, выбирающий машину в аренду, попадет в ДТП и будет в нем виновным.

# %%
# выведем текущие колонки из нашего датафрейм

df_for_model.columns
# Out:
# Index(['county_location', 'distance', 'weather_1', 'direction', 'road_surface',
#        'road_condition_1', 'intersection', 'location_type', 'lighting',
#        'collision_date', 'collision_time', 'at_fault', 'insurance_premium',
#        'cellphone_in_use', 'vehicle_type', 'vehicle_transmission',
#        'vehicle_age', 'collision_datetime', 'month', 'hour', 'part_of_day'],
#       dtype='object')

# %% [markdown]
# Исходя из графиков и предобработки, мы можем исключить следующие параметры из данных:
#
# - collision_date
# - collision_time
# - collision_datetime
# - hour

# %%
# выделим датафрейм по указанным выше условиям

data_model = df_for_model.drop(columns=['collision_date', 'collision_time',
                                        'collision_datetime', 'hour'], axis=1)

data_model.sample(5)
# Out:
#       county_location  distance weather_1 direction road_surface  \
# 5004     contra costa      91.0    cloudy     south          dry
# 53393          fresno       0.0     clear      None          dry
# 32147   san francisco      53.0     clear      west          dry
# 8993       sacramento      30.0     clear      west          dry
# 20981          madera       0.0     clear      None          dry
#
#       road_condition_1  intersection location_type      lighting  at_fault  \
# 5004            normal             0          None      daylight         1
# 53393           normal             1          None      daylight         1
# 32147           normal             0          None      daylight         1
# 8993            normal             0          None      daylight         1
# 20981           normal             1          None  dusk or dawn         1
#
#        insurance_premium  cellphone_in_use vehicle_type vehicle_transmission  \
# ...

# %% [markdown]
# Наш целевой признак `at fault` уже представлен в виде 0/1, и не требует дополнительного кодирования LabelEncoder.

# %%
# проверим на дубликаты

data_model.duplicated().sum()
# Out:
# 346

# %%
# дубликаты образовались потому, что мы исключили часть колонок, обладающих уникальными значениями
# тем не менее, модели дубликаты будут мешать

data_model = data_model.drop_duplicates()
data_model.shape
# Out:
# (54206, 17)

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно! Никакой пользя для модели эти данные не несут
# </div>

# %%
data_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54206 entries, 0 to 56247
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   county_location       54206 non-null  object
#  1   distance              54206 non-null  float64
#  2   weather_1             54041 non-null  object
#  3   direction             42061 non-null  object
#  4   road_surface          53877 non-null  object
#  5   road_condition_1      53970 non-null  object
#  6   intersection          54206 non-null  int32
#  7   location_type         25489 non-null  object
#  8   lighting              54054 non-null  object
#  9   at_fault              54206 non-null  int64
#  10  insurance_premium     54206 non-null  float64
#  11  cellphone_in_use      54206 non-null  int32
#  12  vehicle_type          54206 non-null  object
#  13  vehicle_transmission  53631 non-null  object
#  14  vehicle_age           54206 non-null  float64
# ...

# %%
# обозначим наши типы колонок с данными

cat_cols = ['county_location', 'weather_1', 'direction', 'road_surface',
            'road_condition_1',  'intersection', 'location_type', 'lighting', 
           'cellphone_in_use', 'vehicle_type', 'vehicle_transmission', 'part_of_day']

num_cols = ['distance', 'insurance_premium', 'vehicle_age', 'month']

# %% [markdown]
# Заполнение пропусков в категориальных признаках предполагается заглушкой, и в рамках шага предобработки пайплайна.
#
# Поделим нашу выборку. Соберем пайплайн с предобработкой.

# %%
# поделим выборку на тренировочную и валидационную части

X_train, X_test, y_train, y_test = train_test_split(
                                                 data_model.drop(['at_fault'], axis=1),
                                                 data_model['at_fault'],
                                                 test_size = 0.2, 
                                                 random_state = RANDOM_STATE)

# %%
# выведем размеры выборок

print("Тренировочная выборка:", X_train.shape, y_train.shape)
print("Тестовая выборка:", X_test.shape, y_test.shape)
# Out:
# Тренировочная выборка: (43364, 16) (43364,)
# Тестовая выборка: (10842, 16) (10842,)

# %%
# соберем шаг пайплайна с заменой пропусков и кодировкой категориальных признаков

ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe', 
            SimpleImputer(missing_values=np.nan, strategy='constant', fill_value = 'unknown')
        ),
        
        (
            'ohe', 
            OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)
        )
    ]
)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента v.3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Я видела, что в твоей версии моей тетради на этапе обучения модели сыпались ошибки. Возможно, ты не стала обновлять версию SKLearn? Если ее не обновлять, то не будет работать часть кода в OneHotEncoder с `handle_unknown='ignore'`.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Да, возможно при каком то перезапуске такое случилось (я много раз перезапускала для того, что бы разобраться с заменой времени, до этого все отработало и все успела посмтреть)
# </div>

# %%
# соберем пайплайн с предобработкой

data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, cat_cols),
        ('num', [StandardScaler(), MinMaxScaler()], num_cols)
    ], 
    remainder='passthrough'
)

# %%
# соберем пайплайн для полной модели

pipe_model = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# ## Пятый этап. Поиск лучшей модели

# %% [markdown]
# Будем тестировать модели DecisionTreeClassifier, LogisticRegression и KNeighborsClassifier.

# %% [markdown]
# Необходимо решить, какая метрика нам подойдет лучше всего. Из задания мы знаем, что нам нужно будет отобразить на графике recall и precision. А также рассмотреть матрицу ошибок.
#
# У нас нет пояснения, какое значение `at fault` означает невиновность, а какое - виновность. Класс, который мы хотим предсказать, является "1" (виновен), а оставшийся будет "0" (не виновен).
#
# Можно предположить, что заказчику более важно НЕ ВЫДАТЬ авто клиенту, который попадет в аварию, нежели не выдать машину тому, кто не попадет в аварию. Т.е. нам нужно сосредоточиться на минимизировании FN (ошибки второго рода) - уменьшить количество неверно предсказанного класса "0". Для этого подходит метрика recall.
#
# А можно использовать метрику F1-score, которая является средним гармоническим между precision и recall.
# Или ROC-AUC, которая покажет, насколько хорошо модель разделяет оба класса.
#
# **Воспользуемся метрикой ROC AUC, как наиболее полно учитывающей ошибки модели.**

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Отличное описание выбора метрики!
# </div>

# %% [markdown]
# ### Поиск модели среди классификаторов

# %% [markdown]
# Из-за того, что выводы по данному разделу необходимо представить в виде таблицы, а RandomizedSearch произведет только 10 итераций поиска, я выполню три поиска гиперпараметров для моделей через GridSearch, разделяя их по типу моделей.

# %% [markdown]
# #### Модель DecisionTreeClassifier

# %%
# определим наши гиперпараметры

param_gs_tree = [    
   {
       'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
       'models__min_samples_split': range (5, 10),
       'models__min_samples_leaf': range (5, 10),
       'preprocessor__num': [StandardScaler(), MinMaxScaler()]  
   }, 
]

# %%
# произведем поиск гиперпараметров модели

gs_tree = GridSearchCV(
              pipe_model, 
              param_gs_tree, 
              cv=5,
              scoring='roc_auc', 
              n_jobs=-1
)

gs_tree.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', gs_tree.best_estimator_)
print('Метрика лучшей модели ROC_AUC на тренировочной выборке:', gs_tree.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(fill_value='unknown',
#                                                                                  strategy='constant')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['county_location',
# ...

# %%
# метрика на тестовой выборке для лучшей модели

y_pred_tree = gs_tree.predict_proba(X_test)[:,1]

roc_test_tree = roc_auc_score(y_test, y_pred_tree)

print(f'Метрика ROC-AUC на тестовой выборке: {roc_test_tree}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.6096613479638507

# %%
# посмотрим на лучшую модель с последним набором параметров перебора

pd.set_option('display.max_colwidth', None)

model_tree_rank = pd.DataFrame(gs_tree.cv_results_)

display(model_tree_rank[['rank_test_score', 'mean_test_score','params']].head(1))
# Out:
#    rank_test_score  mean_test_score  \
# 0               41         0.587919
#
#                                                                                                                                                       params
# 0  {'models': DecisionTreeClassifier(random_state=42), 'models__min_samples_leaf': 5, 'models__min_samples_split': 5, 'preprocessor__num': StandardScaler()}

# %%
model_tree_rank['roc_test'] = roc_test_tree
model_tree_r =  model_tree_rank[['mean_test_score','params', 'roc_test']].head(1)

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# #### Модель KNeighborsClassifier

# %%
# определим наши гиперпараметры

param_gs_neigh = [    
   {
       'models': [KNeighborsClassifier()],
       'models__n_neighbors': range(2, 10),
       'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler(), 'passthrough']   
   } 
]

# %%
# произведем поиск гиперпараметров модели

gs_neigh = GridSearchCV(
              pipe_model, 
              param_gs_neigh, 
              cv=5,
              scoring='roc_auc', 
              n_jobs=-1
)

gs_neigh.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', gs_neigh.best_estimator_)
print('Метрика лучшей модели ROC_AUC на тренировочной выборке:', gs_neigh.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(fill_value='unknown',
#                                                                                  strategy='constant')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['county_location',
# ...

# %%
# метрика на тестовой выборке для лучшей модели

y_pred_neigh = gs_neigh.predict_proba(X_test)[:,1]

roc_test_neigh = roc_auc_score(y_test, y_pred_neigh)

print(f'Метрика ROC-AUC на тестовой выборке: {roc_test_neigh}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.6160445333799522

# %%
# посмотрим на лучшую модель с последним набором параметров перебора

model_neigh_rank = pd.DataFrame(gs_neigh.cv_results_)

display(model_neigh_rank[['rank_test_score', 'mean_test_score','params']].head(1))
# Out:
#    rank_test_score  mean_test_score  \
# 0               28         0.554139
#
#                                                                                                 params
# 0  {'models': KNeighborsClassifier(), 'models__n_neighbors': 2, 'preprocessor__num': StandardScaler()}

# %%
model_neigh_rank['roc_test'] = roc_test_neigh
model_neigh_r =  model_neigh_rank[['mean_test_score','params', 'roc_test']].head(1)

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# #### Модель LogisticRegression

# %%
# определим наши гиперпараметры

param_gs_log = [    
    {
       'models': [LogisticRegression(random_state=RANDOM_STATE, max_iter=5000)],
       'models__solver': ['liblinear', 'saga'],
       'models__penalty': ['l1', 'l2'],
#       'models__C': range(1,5),
       'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
   }
]

# %%
# произведем поиск гиперпараметров модели

gs_log = GridSearchCV(
              pipe_model, 
              param_gs_log, 
              cv=5,
              scoring='roc_auc', 
              n_jobs=-1
)

gs_log.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', gs_log.best_estimator_)
print('Метрика лучшей модели ROC_AUC на тренировочной выборке:', gs_log.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(fill_value='unknown',
#                                                                                  strategy='constant')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['county_location',
# ...

# %%
# метрика на тестовой выборке для лучшей модели

y_pred_log = gs_log.predict_proba(X_test)[:,1]

roc_test_log = roc_auc_score(y_test, y_pred_log)

print(f'Метрика ROC-AUC на тестовой выборке: {roc_test_log}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.6606242736207372

# %%
# посмотрим на лучшую модель с последним набором параметров перебора

model_log_rank = pd.DataFrame(gs_log.cv_results_)

display(model_log_rank[['rank_test_score', 'mean_test_score','params']].head(1))
# Out:
#    rank_test_score  mean_test_score  \
# 0                1         0.656159
#
#                                                                                                                                                           params
# 0  {'models': LogisticRegression(max_iter=5000, random_state=42), 'models__penalty': 'l1', 'models__solver': 'liblinear', 'preprocessor__num': StandardScaler()}

# %%
model_log_rank['roc_test'] = roc_test_log
model_log_r =  model_log_rank[['mean_test_score','params', 'roc_test']].head(1)

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# #### Сравнение моделей

# %%
# объеденим показатели лучших моделей

df = [model_tree_r, model_neigh_r, model_log_r]

df_comb = pd.concat(df, ignore_index=True)

df_comb
# Out:
#    mean_test_score  \
# 0         0.587919
# 1         0.554139
# 2         0.656159
#
#                                                                                                                                                           params  \
# 0      {'models': DecisionTreeClassifier(random_state=42), 'models__min_samples_leaf': 5, 'models__min_samples_split': 5, 'preprocessor__num': StandardScaler()}
# 1                                                            {'models': KNeighborsClassifier(), 'models__n_neighbors': 2, 'preprocessor__num': StandardScaler()}
# 2  {'models': LogisticRegression(max_iter=5000, random_state=42), 'models__penalty': 'l1', 'models__solver': 'liblinear', 'preprocessor__num': StandardScaler()}
#
#    roc_test
# 0  0.609661
# 1  0.616045
# 2  0.660624

# %% [markdown]
# **Среди рассмотренных трех типов моделей наилучший результат по метрике ROC AUC показала модель Логистической регрессии.**
#
# Изучим более подробно модель Логистической регресии.

# %% [markdown]
# ## Шестой этап. Анализ метрики лучшей модели

# %% [markdown]
# ### Матрица ошибок, полнота и точность

# %% [markdown]
# Построим для наших данных матрицу ошибок, а также график полноты и точности.

# %%
# введем предсказания в виде меток классов, а не вероятностей

y_pred_log_1 = gs_log.predict(X_test)

# %%
# построим матрицу ошибок

matrix = sklearn.metrics.confusion_matrix(y_test, y_pred_log_1)

sns.heatmap(matrix, annot=True, fmt='d', cmap='Blues_r');

# %% [markdown]
# Весьма значительное количество FN значений.

# %%
# рассчитываем данные для кривой полноты-точности

precision, recall, thresholds = precision_recall_curve(y_test, y_pred_log)

#создаем график

fig, ax = plt.subplots()
ax.plot(recall, precision, color='red')
ax.set_title('Кривая полноты-точности модели')
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')
plt.show()

# %%
# построим еще кривую ROC AUC

RocCurveDisplay.from_estimator(gs_log.best_estimator_, X_test, y_test)
plt.title("График ROC-AUC")
plt.legend()
plt.show()

# %% [markdown]
# ### Анализ важности признаков для модели

# %% [markdown]
# Для изучения важности признаков воспользуемся библиотекой SHAP.

# %%
# обрабатываем данные через шаги пайплайна

X_train_transformed = gs_log.best_estimator_.named_steps['preprocessor'].fit_transform(X_train)
X_test_transformed = gs_log.best_estimator_.named_steps['preprocessor'].transform(X_test)


# "вытаскиваем" названия колонок

feature_names = gs_log.best_estimator_.named_steps['preprocessor'].get_feature_names_out()
explainer_feature_names = feature_names


# инициируем SHAP

explainer = shap.LinearExplainer(gs_log.best_estimator_.named_steps['models'], X_test_transformed,
                                 feature_names=explainer_feature_names)

# %%
# рассчитываем значения "важности"

shap_values = explainer(X_test_transformed)
shap_values.shape
# Out:
# (10842, 101)

# %%
shap.plots.bar(shap_values)

# %% [markdown]
# После обработки кодировщиком, модель получила для изучения 101 признак. И она считает, что вероятность оказаться виноватым в ДТП повышается, если:
# - вы арендовали седан;
# - у вас высокая стоимость страховой выплаты;
# - вы едете ночью:
# - по любому типу дороги, но в Лос Анджелесе;
# - проезжаете перекрестки на автомобиле с ручной коробкой передач.

# %% [markdown]
# ~~Какие можно сделать выводы:~~
# ~~- наиболее важным признаком является вождение с нарушением правил дорожного движения.~~
# ~~- ожидаемо, что вторым наиболее влиятельным признаком окажется наличие алкоголя в крови водителя.~~
# ~~- далее, идет не причина, но следствие - столкновение с другим автомобилем.~~
# ~~- четвертый признак - отсутствие алкоголя в крови. Это уже необычно.~~
# ~~- далее идет количество участников ДТП - опять же, следствие.~~
# ~~- и далее еще одна причина нарушения - вождение под воздействием чего-либо "Driving or Bicycling Under the Influence of ~~Alcohol or Drug".~~
#
# ~~*После перепроведения тетради признаки немного поменялись местами. Но в общем, они все также на первых шести строках.*~~
#
# ~~С одной стороны, мы видим, что модель оперирует уже свершившимися фактами - ДТП произошло, и оно обладало следующими признаками. Это не слишком помогает **предсказать** вероятность того, что машина владельца каршеринга попадет в аварию.   ~~
#
# ~~С другой стороны, далеко не все данные доступны гипотетической модели, чтобы вынести свою оценку. Например, тот же рассматриваемый в примере алкотестер - чтобы его данные были законны, он должен быть поверен, и размещен на законных основаниях. Я не уверена, что текущее законодательство разрешает использовать подобные приборы частным компаниям, и принимать решения на основе таких измерений.~~
#
# ~~Получается, что когда мы (по установленным в условии правилам) отбирали признаки без проверки их на корреляцию, просто ожидая, что модель сама решит, какие признаки ей важны, мы получили важные признаки из тех, что относятся к **"последствиям" ДТП, не к "причинам".**~~
#
# ~~А если теперь мы будем отбирать только те признаки, которые мы можем знать до совершания клиентом поездки, то это будет очень скромная подборка.~~

# %%
shap.plots.beeswarm(shap_values, max_display=10)

# %% [markdown]
# При таком количестве категориальных признаков, тип графика "пчелиный улей" совсем не показателен.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Отличный анализ важности факторов!
# </div>

# %% [markdown]
# ### Влияние одного из важных признаков на целевой показатель

# %% [markdown]
# Изучим влияние **"времени суток"** на статистику виновности.

# %%
sns.countplot(data=data_model, y='part_of_day', hue='at_fault')
plt.title('Сравнение причин ДТП в 2012 от времени суток')
plt.xlabel('Количество ДТП')
plt.ylabel('Время суток')
plt.legend(['не виновен', 'виновен'])
plt.show()

# %% [markdown]
# Исходя из графика, основное количество ДТП происходит в дневное время, однако в случае ДТП, происходящих в ночное время, увеличивается вероятность того, что участник такого ДТП будет в нем виновен.
#
# В качестве дополнения к данному признаку можно изучить влияние уровня освещенности. Мы можем предполагать, что риск попасть в ДТП ночью увеличивается за счет естественного снижения уровня освещенности, а также по причине типичных биоритмов человека - ночью реакция обычно замедляется.

# %%
sns.catplot(data=data_model, y="part_of_day", col="lighting", 
            kind="count", col_wrap=2, height=3, aspect=1.2);

# %% [markdown]
# Вечером и ночью учащаются случаи ДТП в местах с отсутствием уличного освещения. Количество аварий в то же время суток, но на улицах с работающим освещением, примерно в два раза ниже.

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Все верно!
# </div>

# %% [markdown]
# ## Седьмой этап. Общий вывод

# %% [markdown]
# В этом проекте мы пытались создать модель для предсказания ДТП при сдаче автомобиля в аренду. Эта задача является задачей классификации, и нашим целевым признаком была виновность участника ДТП.
# В качестве типов моделей мы выбрали DecisionTreeClassifier, KNeighbourClassifier и LogisticRegression.
# Отбор признаков для обучения производился без проверки на корреляцию. Возможно, мы неверно поняли условие задания, и нам не предлагали пропустить этот этап.
# ~~Тем не менее, признаки отбирались исходя из их описания и графика распределения. Так, например, признак "расстояния от главной дороги" оказался чрезмерно подвержен выборосам, из-за чего был исключен из обучения.   ~~
#
# Данные были поделены на тренировочную и тестовую выборку. Перед обучением моделей параметры были подверждены обработке через SimpleImputer и OneHotEncoder посредством Pipeline. Каждый тип модели тестировался на переборе своих гиперпараметров, и данные лучшей модели заносились в таблицу. При тестировании модели использовалась кросс-валидация, поэтому нам не нужна была валидационная выборка для проверки моделей.
#
# Модель Дерева Решений и Логистической Регрессии показали весьма близкие результаты. Модель К Ближайших соседей отстает в метрике примерно на 10%. В качестве метрики была выбрана ROC AUC, как наиболее полно учитывающая присвоение метки классов моделью. Значание метрики для лучших моделей составило 65%.
#
# Не уверена, что значение метрики можно улучшить. Мы использовали модель с регуляризацией, а значит, незначительные признаки не оказывали влияния на нашу модель. Т.е. уменьшение признаков не оказало бы сильного влияния на модель. Также я отметила неоднородность данных по ДТП за 2012 год в разрезе разделения аваний по месяцам - почему-то после июня резко сократилось количество аварий в выборке. Для данных за весь период такого явления не наблюдалось.
#
# ~~Среди признаков, не взятых в обучение модели, я не нахожу кандидатов, которые могли бы существенно улучшить модель.~~

# %% [markdown]
# **С точки зрения оценки возможности создания адекватной системы оценки риска при выдаче авто:** не опираясь только на данные модели, но также на свой жизненный опыт, могу предположить следующее:
# - в ДТП в большинстве случаев участвуют два и более водителя авто.
# - мы пытаемся оценить риск только для одного из участников, поведение второго гипотетического участника ДТП нам неизвестно.
# - большая часть ДТП происходит по причине нарушений ПДД - нарушение скоростного режима, правил поворота и правил преимущества движения авто. Можно попытаться узнавать **историю правонарушений водителя**, который приходит арендовать авто, и, также, **вести собственную статистику поведения клиента за рулем**. Разработать правила, какое количество или какого рода нарушения ПДД влекут за собой отказ в аренде авто.
# - отдельная категория ДТП связана с водителями, находящимися в состоянии алкогольного илил наркотического опьянения. Я не уверена в правомочности проведения проверок на этот параметр. Если это допустимо по закону, например, если компания заказчика обладает поверенным оборудованием для выявления наличия алкоголя и/или наркотиков в организме, то в случае сомнений у менеджера (если автомобиль арендуется лично), можно просить клиента пройти осмотр. Отказ пройти осмотр будет являться причиной для отказа в аренде авто. Но вот в случае обезличенного сервиса каршеринга, я не думаю,что существует достаточно надежный и защищенный прибор для подобных проверок. Опять же, он должен находиться внутри авто.
#
# Мне кажется более вероятным развитие такой проверки в сторону камеры внутри автомобиля, направленной на водительское место, которая бы обрабатывала изображение в реальном времени с помощью ИИ. Продумать алгоритм проверки (голосовые запросы, время на подключение всех сервисов), чтобы ИИ мог проанализировать поведение водителя.

# %% [markdown]
# В общем, если проверять историю нарушений водителем ПДД и анализировать статистику своих клиентов - то и модель не нужна.

# %% [markdown]
# <div class="alert alert-warning">
# <b>🤔 Рекомендация:</b> Я постаралась ответить на все твои вопросы, в работе сейчас уже все почти хорошо, осталось исправить все не получившиемся моменты (заполнение временем, отбор признаков, оформление графиков), то есть работа пос=чти готова, все очень хорогшо получилось. Если еще есть вопросы - задавай!
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>👍 Успех:</b> Отличная работа! Было очень приятно проверять твой проект!
#
# Оставлю хороший учебник по ML:
# +  https://academy.yandex.ru/handbook/ml
#
# Немного новостей с мира DL(вдруг заинтересует):
# +  https://habr.com/ru/company/ods/blog/686962/
#
# Вот тут проходят всякие соревнования, можешь себя попробовать:
# +  https://hacks-ai.ru/
#
#
# Возможно, что нить пригодится:
# +  https://arxiv.org/ftp/arxiv/papers/2201/2201.00650.pdf
# +  https://github.com/slgero/testovoe
#
#
# Курс от МФТИ математика для DS:
#
# +  https://www.youtube.com/watch?v=xccjt6lOoow&list=PLk4h7dmY2eYHHTyfLyrl7HmP-H3mMAW08&index=1
#
#
# Тут много соревнований/лекций:
#
# +  https://ods.ai/
#
# stepic NLP/CV:
#
# +  https://stepik.org/course/54098/syllabus
# +  https://stepik.org/course/50352/syllabus
#
# Еще есть от ВШЭ:
#
# +  https://www.youtube.com/watch?v=mwjQaNt8qxk&list=PLEwK9wdS5g0og-DcF1apxutSM0GDLHz_3&ab_channel=%D0%A4%D0%9A%D0%9D%D0%92%D0%A8%D0%AD%E2%80%94%D0%B4%D0%B8%D1%81%D1%82%D0%B0%D0%BD%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D0%B5%D0%B7%D0%B0%D0%BD%D1%8F%D1%82%D0%B8%D1%8F
# +  https://github.com/hse-ds/iad-deep-learning
#
# Удачи в следующих проектах!!!
# </div>
